# %% [markdown]
# Mahesh Rao
#
#
# Jan 22, 2020

# %% [markdown]
# Apologies, this notebook is very messy. I'll try to clean it up over time. Basically this contains code I used to generate the database file to make an ERD for data question 2 for the analytics jumpstart

# %%
import pandas as pd
import string
import sqlite3 as sql
from sqlalchemy import MetaData, Table, Column, Integer, String, Float, DateTime, ForeignKey, create_engine, insert
from eralchemy import render_er

# %%
pd.set_option('display.max_columns', None)

# %%
permits = pd.read_csv('data/Building_Permits_Issued.csv', low_memory=False)
short_term_permits = pd.read_csv('data/Residential_Short_Term_Rental_Permits.csv')

# %%
short_term_permits.columns
# Out:
# Index(['Permit #', 'Applicant', 'Applicant Home Phone',
#        'Applicant Mobile Phone', 'Applicant Work Phone',
#        'Applicant Work Phone Ext.', 'Contact', 'Contact Home Phone',
#        'Contact Mobile Phone', 'Contact Work Phone', 'Contact Work Phone Ext.',
#        'Permit Subtype Description', 'Permit Status', 'Parcel', 'Date Entered',
#        'Date Issued', 'Expiration Date', 'Address', 'City', 'State', 'ZIP',
#        'Subdivision / Lot', 'Purpose', 'Permit Owner Name',
#        'Permit Owner Addr. 1', 'Permit Owner Addr. 2', 'Permit Owner Addr. 3',
#        'Permit Owner City', 'Permit Owner State', 'Permit Owner ZIP',
#        'Permit Type', 'Permit Subtype', 'Council District', 'Census Tract',
#        'Mapped Location'],
#       dtype='object')

# %%
def make_table_input(df, table_name, primary_key = None, foreign_key = None):
    '''
    Function to print out the function input to make a sqlalchemy table
    
    foreign_key arg requires a list of tuples or lists with 2 elements: (col_name, reference_df.reference_col_name)
    '''
    column_list = []
    for c in df.columns:
        arg = "Column('{}', {}".format(c, df[c].dtype)
        if foreign_key is not None:
            for f_key in foreign_key:
                if f_key[0]==c:
                    arg += ", ForeignKey('{}')".format(f_key[1])
        if primary_key == c:
            arg += ", primary_key=True"
        arg += ")"
        column_list.append(arg)
    concat_args = ", \n".join(column_list).replace('object', 'String').replace('float64', 'Float').replace('int64', 'Integer').replace('datetime64[ns]', 'DateTime')
    return "Table('{}', metadata, \n".format(table_name)+concat_args+')'

# %%
print(make_table_input(permits, 'permits', primary_key = 'Permit #'))
# Out:
# Table('permits', metadata,
# Column('Permit #', String, primary_key=True),
# Column('Permit Type Description', String),
# Column('Permit Subtype Description', String),
# Column('Parcel', String),
# Column('Date Entered', String),
# Column('Date Issued', String),
# Column('Construction Cost', Float),
# Column('Address', String),
# Column('City', String),
# Column('State', String),
# Column('ZIP', Integer),
# Column('Subdivision / Lot', String),
# Column('Contact', String),
# Column('Permit Type', String),
# Column('Permit Subtype', String),
# Column('IVR Tracking #', Integer),
# Column('Purpose', String),
# Column('Council District', Float),
# Column('Census Tract', Float),
# Column('Mapped Location', String))

# %%
print(make_table_input(short_term_permits, 'short_term', primary_key = 'Permit #', foreign_key = ('Permit #', 'permits.Permit #', )))
# Out:
# Table('short_term', metadata,
# Column('Permit #', String, primary_key=True),
# Column('Applicant', String),
# Column('Applicant Home Phone', String),
# Column('Applicant Mobile Phone', String),
# Column('Applicant Work Phone', String),
# Column('Applicant Work Phone Ext.', String),
# Column('Contact', String),
# Column('Contact Home Phone', String),
# Column('Contact Mobile Phone', String),
# Column('Contact Work Phone', String),
# Column('Contact Work Phone Ext.', String),
# Column('Permit Subtype Description', String),
# Column('Permit Status', String),
# Column('Parcel', String),
# Column('Date Entered', String),
# Column('Date Issued', String),
# Column('Expiration Date', String),
# Column('Address', String),
# Column('City', String),
# Column('State', String),
# Column('ZIP', Integer),
# Column('Subdivision / Lot', String),
# Column('Purpose', String),
# Column('Permit Owner Name', String),
# Column('Permit Owner Addr. 1', String),
# Column('Permit Owner Addr. 2', String),
# Column('Permit Owner Addr. 3', String),
# Column('Permit Owner City', String),
# Column('Permit Owner State', String),
# Column('Permit Owner ZIP', String),
# Column('Permit Type', String),
# Column('Permit Subtype', String),
# Column('Council District', Float),
# Column('Census Tract', Integer),
# Column('Mapped Location', String))

# %%
from sqlalchemy import (MetaData, Table, Column, Integer, String, Float, ForeignKey) 

metadata = MetaData()

permits_table = Table('permits', metadata, 
                      Column('Permit #', String, primary_key=True), 
                      Column('Permit Type Description', String), 
                      Column('Permit Subtype Description', String), 
                      Column('Parcel', String), 
                      Column('Date Entered', String), 
                      Column('Date Issued', String), 
                      Column('Construction Cost', Float), 
                      Column('Address', String), 
                      Column('City', String), 
                      Column('State', String), 
                      Column('ZIP', Integer), 
                      Column('Subdivision / Lot', String), 
                      Column('Contact', String), 
                      Column('Permit Type', String), 
                      Column('Permit Subtype', String), 
                      Column('IVR Tracking #', Integer), 
                      Column('Purpose', String), 
                      Column('Council District', Float), 
                      Column('Census Tract', Float), 
                      Column('Mapped Location', String))

# %%
short_term_table = Table('short_term', metadata, 
                         Column('Permit #', String, ForeignKey('permits.Permit #'), primary_key=True), 
                         Column('Applicant', String), 
                         Column('Applicant Home Phone', String), 
                         Column('Applicant Mobile Phone', String), 
                         Column('Applicant Work Phone', String), 
                         Column('Applicant Work Phone Ext.', String), 
                         Column('Contact', String), 
                         Column('Contact Home Phone', String), 
                         Column('Contact Mobile Phone', String), 
                         Column('Contact Work Phone', String), 
                         Column('Contact Work Phone Ext.', String), 
                         Column('Permit Subtype Description', String), 
                         Column('Permit Status', String), 
                         Column('Parcel', String), 
                         Column('Date Entered', String), 
                         Column('Date Issued', String), 
                         Column('Expiration Date', String), 
                         Column('Address', String), 
                         Column('City', String), 
                         Column('State', String), 
                         Column('ZIP', Integer), 
                         Column('Subdivision / Lot', String), 
                         Column('Purpose', String), 
                         Column('Permit Owner Name', String), 
                         Column('Permit Owner Addr. 1', String), 
                         Column('Permit Owner Addr. 2', String), 
                         Column('Permit Owner Addr. 3', String), 
                         Column('Permit Owner City', String), 
                         Column('Permit Owner State', String), 
                         Column('Permit Owner ZIP', String), 
                         Column('Permit Type', String), 
                         Column('Permit Subtype', String), 
                         Column('Council District', Float), 
                         Column('Census Tract', Integer), 
                         Column('Mapped Location', String))

# %% [markdown]
# ---

# %%
# download from https://data.nashville.gov/General-Government/Metro-Resident-Survey-Responses/nux7-cwab
survey = pd.read_csv('extra_data/Metro_Resident_Survey_Responses.csv', low_memory=False)
# download from https://data.nashville.gov/Licenses-Permits/Building-Permits-Issued/3h5w-q8b7
permits = pd.read_csv('permits_erd_test.csv', low_memory=False, index_col = 0)
# download from https://data.nashville.gov/Fire/Fire-Stations/frq9-a5iv
stations_district = pd.read_csv('stations_erd_test.csv', low_memory=False, index_col = 0)
# download from https://data.nashville.gov/Licenses-Permits/Residential-Short-Term-Rental-Permits/2z82-v8pm
short = pd.read_csv('short_erd_test.csv', low_memory=False, index_col = 0)

# %%
survey = survey.reset_index().rename(columns = {'index':'id'})
new_col = []
for i in survey.columns:
    new_i = i.lower().strip().replace('-', ' ')
    new_i = new_i.translate(str.maketrans('', '', string.punctuation)).replace('  ', ' ').replace(' ', '_')
    new_col.append(new_i)
survey.columns = new_col
survey_fire = survey[['id', 'zip_code', 'period', 'start_date', 'end_date', 'short_term_rental_enforcement', 'city_appearance', 'neighborhood_appearance', 'nashville_as_residence', 'nashville_as_place_to_raise_children','nashville_as_workplace','nashville_as_place_to_startgrow_business','nashville_as_retirement_place']+[c for c in survey.columns if 'fire' in c]]

# %%
survey_fire_2018 = survey_fire[survey_fire['period'].str.contains('2018Q3')]

# %%
survey_fire_2018_single_list = []
for z in survey_fire_2018['zip_code'].unique():
    survey_fire_2018_single_list.append(survey_fire_2018[survey_fire_2018['zip_code']==z].mode().loc[[0]])
survey_fire_2018_single = pd.concat(survey_fire_2018_single_list)

# %%
# Final version
survey_fire_2018_single = survey_fire_2018_single.reset_index(drop=True)

# %%
# Need to figure out what to do about this
permits[permits['number']=='2017011225']
# Out:
#            number                   type_desc  \
# 10971  2017011225  Building Demolition Permit
# 11067  2017011225  Building Demolition Permit
# 11941  2017011225  Building Demolition Permit
# 14442  2017011225  Building Demolition Permit
# 27293  2017011225  Building Demolition Permit
# 31099  2017011225  Building Demolition Permit
# 32721  2017011225  Building Demolition Permit
#
#                           subtype_desc          parcel  enter_date  \
# 10971  Demolition Permit - Residential  083031F90000CO  2017-02-16
# 11067  Demolition Permit - Residential  083031G00100CO  2017-02-16
# 11941  Demolition Permit - Residential  083031G90000CO  2017-02-16
# 14442  Demolition Permit - Residential  083031F00100CO  2017-02-16
# 27293  Demolition Permit - Residential     08303014300  2017-02-16
# 31099  Demolition Permit - Residential  083031G00200CO  2017-02-16
# 32721  Demolition Permit - Residential  083031F00200CO  2017-02-16
#
#        issue_date    cost           address       city state    zip  \
# 10971  2017-02-16  5000.0  1301F  PORTER RD  NASHVILLE    TN  37206
# 11067  2017-02-16  5000.0  1301A  PORTER RD  NASHVILLE    TN  37206
# 11941  2017-02-16  5000.0  1301E  PORTER RD  NASHVILLE    TN  37206
# 14442  2017-02-16  5000.0  1301C  PORTER RD  NASHVILLE    TN  37206
# 27293  2017-02-16  5000.0   1301  PORTER RD  NASHVILLE    TN  37206
# 31099  2017-02-16  5000.0  1301B  PORTER RD  NASHVILLE    TN  37206
# 32721  2017-02-16  5000.0  1301D  PORTER RD  NASHVILLE    TN  37206
#
#                                         subdivision  \
# 10971       COMMON AREA 1301D PORTER ROAD TOWNHOMES
# 11067            UNIT A 1301A PORTER ROAD TOWNHOMES
# 11941       COMMON AREA 1301A PORTER ROAD TOWNHOMES
# 14442            UNIT C 1301D PORTER ROAD TOWNHOMES
# 27293  LOTS 28 AND 29 MARTINS SUB 58 59 BROWNSVILLE
# 31099            UNIT B 1301A PORTER ROAD TOWNHOMES
# 32721            UNIT D 1301D PORTER ROAD TOWNHOMES
#
#                            contact type_code subtype_code  tracking_number  \
# 10971  L & S CONSTRUCTION SERVICES      CADM    CAZ01A001          3321232
# 11067  L & S CONSTRUCTION SERVICES      CADM    CAZ01A001          3321232
# 11941  L & S CONSTRUCTION SERVICES      CADM    CAZ01A001          3321232
# 14442  L & S CONSTRUCTION SERVICES      CADM    CAZ01A001          3321232
# 27293  L & S CONSTRUCTION SERVICES      CADM    CAZ01A001          3321232
# 31099  L & S CONSTRUCTION SERVICES      CADM    CAZ01A001          3321232
# 32721  L & S CONSTRUCTION SERVICES      CADM    CAZ01A001          3321232
#
#                                                  purpose  council_district  \
# 10971  To demo existing single family residence and a...               7.0
# 11067  To demo existing single family residence and a...               7.0
# 11941  To demo existing single family residence and a...               7.0
# 14442  To demo existing single family residence and a...               7.0
# 27293  To demo existing single family residence and a...               7.0
# 31099  To demo existing single family residence and a...               7.0
# 32721  To demo existing single family residence and a...               7.0
#
#        census_tract                                    mapped_location  \
# 10971    37011400.0  1301F PORTER RD\nNASHVILLE, TN 37206\n(36.1896...
# 11067    37011400.0  1301A PORTER RD\nNASHVILLE, TN 37206\n(36.1896...
# 11941    37011400.0  1301E PORTER RD\nNASHVILLE, TN 37206\n(36.1896...
# 14442    37011400.0  1301C PORTER RD\nNASHVILLE, TN 37206\n(36.1896...
# 27293    37011400.0  1301 PORTER RD\nNASHVILLE, TN 37206\n(36.18966...
# 31099    37011400.0  1301B PORTER RD\nNASHVILLE, TN 37206\n(36.1896...
# 32721    37011400.0  1301D PORTER RD\nNASHVILLE, TN 37206\n(36.1896...
#
#        issue_year                      lapse
# 10971        2017  0 days 00:00:00.000000000
# 11067        2017  0 days 00:00:00.000000000
# 11941        2017  0 days 00:00:00.000000000
# 14442        2017  0 days 00:00:00.000000000
# 27293        2017  0 days 00:00:00.000000000
# 31099        2017  0 days 00:00:00.000000000
# 32721        2017  0 days 00:00:00.000000000

# %%
permits['num_parcel_add'] = permits['number']+permits['parcel']+permits['address'].str.split(' ').str[0]

# %%
permits = permits.drop_duplicates([c for c in permits.columns if c not in ['contact', 'address', 'mapped_location']])

# %%
permits_2018 = permits[permits['issue_year']==2018]

# %%
permits_2018['issue_year'].value_counts()
# Out:
# 2018    11080
# Name: issue_year, dtype: int64

# %%
short['id_parcel'] = short['id'].astype(str)+short['parcel'].astype(str)

# %%
short['id_parcel'].value_counts()
# Out:
# 201802303911603006300       2
# 201700630109313010400       2
# 2019013143072090T00100CO    1
# 201803786208313025500       1
# 201801116708305018900       1
#                            ..
# 201705703610302024200       1
# 2017028113092100B00400CO    1
# 2019039891092090U00200CO    1
# 2019005521091110V00800CO    1
# 201902700608213040100       1
# Name: id_parcel, Length: 3360, dtype: int64

# %%
short[short['id_parcel']=='201802303911603006300']
# Out:
#               id                                applicant  \
# 3275  2018023039  ANDREWS, ERNEST ALBERT III & NITA BAUGH
# 6024  2018023039  ANDREWS, ERNEST ALBERT III & NITA BAUGH
#
#                                       contact  \
# 3275                             Nita Andrews
# 6024  ANDREWS, ERNEST ALBERT III & NITA BAUGH
#
#                             subtype_desc  status       parcel  \
# 3275  Short Term Rental - Owner Occupied  ISSUED  11603006300
# 6024  Short Term Rental - Owner Occupied  ISSUED  11603006300
#
#                      entered      issued              expiration  \
# 3275  04/24/2018 12:00:00 AM  2018-05-04  05/04/2020 12:00:00 AM
# 6024  04/24/2018 12:00:00 AM  2018-05-04  05/04/2020 12:00:00 AM
#
#                address       city state    zip  \
# 3275  130A  KENNER AVE  NASHVILLE    TN  37205
# 6024  130A  KENNER AVE  NASHVILLE    TN  37205
#
#                                                 purpose  \
# 3275  By making this application for a Residential S...
# 6024  By making this application for a Residential S...
#
#                             permit_owner_name  type  council_district  \
# 3275  ANDREWS, ERNEST ALBERT III & NITA BAUGH  CASR              24.0
# 6024  ANDREWS, ERNEST ALBERT III & NITA BAUGH  CASR              24.0
#
#                   id_parcel
# 3275  201802303911603006300
# 6024  201802303911603006300

# %%
short = short.drop_duplicates([c for c in short.columns if c != 'contact'])

# %%
short['issued'] = pd.to_datetime(short['issued'])

# %%
short_2018 = short[short['issued'].dt.year==2018]#.sort_values('issued')

# %%
stations_district
# Out:
#     district                          station_number
# 0          1                          ['Station 30']
# 1          2             ['Station 24' 'Station 25']
# 2          3                          ['Station 39']
# 3          5                           ['Station 3']
# 4          6                          ['Station 14']
# 5          7             ['Station 29' 'Station 18']
# 6          8              ['Station 1' 'Station 31']
# 7          9                          ['Station 38']
# 8         11                          ['Station 36']
# 9         13              ['Station 15' 'Station 4']
# 10        14                          ['Station 32']
# 11        15             ['Station 22' 'Station 28']
# 12        16                          ['Station 21']
# 13        17  ['Station 12' 'Station 8' 'Station 5']
# 14        18                          ['Station 16']
# 15        19               ['Station 9' 'Station 2']
# 16        20                          ['Station 23']
# 17        21             ['Station 11' 'Station 19']
# 18        22                          ['Station 37']
# 19        23                           ['Station 7']
# 20        24             ['Station 13' 'Station 17']
# 21        25                          ['Station 20']
# 22        26                          ['Station 27']
# 23        27                          ['Station 10']
# 24        29                          ['Station 33']
# 25        30                           ['Station 6']
# 26        32                          ['Station 26']
# 27        33                          ['Station 35']

# %%
for d in list(range(1, 34)):
    if d not in stations_district['district'].tolist():
#         print(d)
#         print(pd.DataFrame(data = {'district':d, 'station_number':[]}))
        stations_district = stations_district.append(pd.DataFrame(data = {'district':[d], 'station_number':['[]']}))

# %%
stations_district = stations_district.sort_values('district').reset_index(drop=True)

# %%
stations_district
# Out:
#     district                          station_number
# 0          1                          ['Station 30']
# 1          2             ['Station 24' 'Station 25']
# 2          3                          ['Station 39']
# 3          4                                      []
# 4          5                           ['Station 3']
# 5          6                          ['Station 14']
# 6          7             ['Station 29' 'Station 18']
# 7          8              ['Station 1' 'Station 31']
# 8          9                          ['Station 38']
# 9         10                                      []
# 10        11                          ['Station 36']
# 11        12                                      []
# 12        13              ['Station 15' 'Station 4']
# 13        14                          ['Station 32']
# 14        15             ['Station 22' 'Station 28']
# 15        16                          ['Station 21']
# 16        17  ['Station 12' 'Station 8' 'Station 5']
# 17        18                          ['Station 16']
# 18        19               ['Station 9' 'Station 2']
# 19        20                          ['Station 23']
# 20        21             ['Station 11' 'Station 19']
# 21        22                          ['Station 37']
# 22        23                           ['Station 7']
# 23        24             ['Station 13' 'Station 17']
# 24        25                          ['Station 20']
# 25        26                          ['Station 27']
# 26        27                          ['Station 10']
# 27        28                                      []
# 28        29                          ['Station 33']
# 29        30                           ['Station 6']
# 30        31                                      []
# 31        32                          ['Station 26']
# 32        33                          ['Station 35']

# %%
print(make_table_input(permits_2018, 'permits_2018', primary_key = 'num_parcel_add', foreign_key = [('parcel', 'strp_2018.parcel'), ('council_district', 'station_dist.district'), ('zip', 'resident_survey_2018.zip_code')]))
print('\n')
print(make_table_input(short_2018, 'strp_2018', primary_key = 'id', foreign_key = [('parcel', 'permits_2018.parcel'), ('council_district', 'station_dist.district'), ('zip', 'resident_survey_2018.zip_code')]))
print('\n')
print(make_table_input(stations_district, 'station_dist', primary_key = 'district'))
print('\n')
print(make_table_input(survey_fire_2018_single, 'resident_survey_2018', primary_key = 'id'))
# Out:
# Table('permits_2018', metadata,
# Column('number', String),
# Column('type_desc', String),
# Column('subtype_desc', String),
# Column('parcel', String, ForeignKey('strp_2018.parcel')),
# Column('enter_date', String),
# Column('issue_date', String),
# Column('cost', Float),
# Column('address', String),
# Column('city', String),
# Column('state', String),
# Column('zip', Integer, ForeignKey('resident_survey_2018.zip_code')),
# Column('subdivision', String),
# Column('contact', String),
# Column('type_code', String),
# Column('subtype_code', String),
# Column('tracking_number', Integer),
# Column('purpose', String),
# Column('council_district', Float, ForeignKey('station_dist.district')),
# Column('census_tract', Float),
# Column('mapped_location', String),
# Column('issue_year', Integer),
# Column('lapse', String),
# Column('num_parcel_add', String, primary_key=True))
#
#
# Table('strp_2018', metadata,
# Column('id', String, primary_key=True),
# Column('applicant', String),
# Column('contact', String),
# Column('subtype_desc', String),
# Column('status', String),
# Column('parcel', String, ForeignKey('permits_2018.parcel')),
# Column('entered', String),
# Column('issued', DateTime),
# Column('expiration', String),
# Column('address', String),
# Column('city', String),
# Column('state', String),
# Column('zip', Integer, ForeignKey('resident_survey_2018.zip_code')),
# Column('purpose', String),
# Column('permit_owner_name', String),
# Column('type', String),
# Column('council_district', Float, ForeignKey('station_dist.district')),
# Column('id_parcel', String))
#
#
# Table('station_dist', metadata,
# Column('district', Integer, primary_key=True),
# Column('station_number', String))
#
#
# Table('resident_survey_2018', metadata,
# Column('id', Integer, primary_key=True),
# Column('zip_code', Float),
# Column('period', String),
# Column('start_date', String),
# Column('end_date', String),
# Column('short_term_rental_enforcement', String),
# Column('city_appearance', String),
# Column('neighborhood_appearance', String),
# Column('nashville_as_residence', String),
# Column('nashville_as_place_to_raise_children', String),
# Column('nashville_as_workplace', String),
# Column('nashville_as_place_to_startgrow_business', String),
# Column('nashville_as_retirement_place', String),
# Column('fire_and_ems__overall', String),
# Column('fire_services', String),
# Column('fire_response_time', String),
# Column('fire_professionalism', String))

# %%
db_uri = 'sqlite:///multi_table_2.db'
engine = create_engine(db_uri)
connection = engine.connect()
metadata = MetaData(engine)

permits_table = Table('permits_2018', metadata, 
Column('number', String), 
Column('type_desc', String), 
Column('subtype_desc', String), 
Column('parcel', String, ForeignKey('strp_2018.parcel')), 
Column('enter_date', String), 
Column('issue_date', String), 
Column('cost', Float), 
Column('address', String), 
Column('city', String), 
Column('state', String), 
Column('zip', Integer, ForeignKey('resident_survey_2018.zip_code')), 
Column('subdivision', String), 
Column('contact', String), 
Column('type_code', String), 
Column('subtype_code', String), 
Column('tracking_number', Integer), 
Column('purpose', String), 
Column('council_district', Float, ForeignKey('station_dist.district')), 
Column('census_tract', Float), 
Column('mapped_location', String), 
Column('issue_year', Integer), 
Column('lapse', String), 
Column('num_parcel_add', String, primary_key=True))

short_table = Table('strp_2018', metadata, 
Column('id', String, primary_key=True), 
Column('applicant', String), 
Column('contact', String), 
Column('subtype_desc', String), 
Column('status', String), 
Column('parcel', String, ForeignKey('permits_2018.parcel')), 
Column('entered', String), 
Column('issued', DateTime), 
Column('expiration', String), 
Column('address', String), 
Column('city', String), 
Column('state', String), 
Column('zip', Integer, ForeignKey('resident_survey_2018.zip_code')), 
Column('purpose', String), 
Column('permit_owner_name', String), 
Column('type', String), 
Column('council_district', Float, ForeignKey('station_dist.district')), 
Column('id_parcel', String))

station_dist_table = Table('station_dist', metadata, 
Column('district', Integer, primary_key=True), 
Column('station_number', String))

survey_table = Table('resident_survey_2018', metadata, 
Column('id', Integer, primary_key=True), 
Column('zip_code', Float), 
Column('period', String), 
Column('start_date', String), 
Column('end_date', String), 
Column('short_term_rental_enforcement', String), 
Column('city_appearance', String), 
Column('neighborhood_appearance', String), 
Column('nashville_as_residence', String), 
Column('nashville_as_place_to_raise_children', String), 
Column('nashville_as_workplace', String), 
Column('nashville_as_place_to_startgrow_business', String), 
Column('nashville_as_retirement_place', String), 
Column('fire_and_ems__overall', String), 
Column('fire_services', String), 
Column('fire_response_time', String), 
Column('fire_professionalism', String))

# permits_table.create()
# short_table.create()
# station_dist_table.create()
# survey_table.create()

metadata.create_all(engine)

# %%
# if get IntegrityError, its because multi_table_2.db already exists. Shortcut is to just delete the file and then rerun this

for table, df in zip([station_dist_table, permits_table, short_table, survey_table], [stations_district, permits_2018, short_2018, survey_fire_2018_single]):
    print(table)
    query = insert(table)
#     print(query)
    values_list = list(df.to_dict(orient='index').values())
#     print(values_list)
    ResultProxy = connection.execute(query,values_list)
# Out:
# station_dist
# permits_2018
# strp_2018
# resident_survey_2018

# %%
filename = 'mymodel.png'
render_er(metadata, filename)

# ERD will output as mymodel.png at the same directory level as this notebook

# %%
db = 'multi_table_2.db'
con = sql.connect(db)
mycursor = con.cursor() 
mycursor.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
tables=(mycursor.fetchall())
print(tables)
# Out:
# [('permits_2018',), ('resident_survey_2018',), ('station_dist',), ('strp_2018',)]

# %%
survey_fire_2018_single.merge(short_2018, how = 'inner', left_on = 'zip_code', right_on = 'zip').merge(stations_district, how = 'right', left_on = 'council_district', right_on = 'district')[['district', 'station_number', 'fire_and_ems__overall', 'fire_services', 'fire_response_time', 'fire_professionalism']].drop_duplicates('district')
# Out:
#      district                          station_number fire_and_ems__overall  \
# 0           6                          ['Station 14']             Satisfied
# 57          5                           ['Station 3']             Satisfied
# 128         7             ['Station 29' 'Station 18']             Satisfied
# 161        11                          ['Station 36']             Satisfied
# 164         8              ['Station 1' 'Station 31']             Satisfied
# 181        25                          ['Station 20']             Satisfied
# 183        24             ['Station 13' 'Station 17']             Satisfied
# 204        20                          ['Station 23']             Satisfied
# 231        21             ['Station 11' 'Station 19']             Satisfied
# 344        26                          ['Station 27']             Satisfied
# 354        33                          ['Station 35']             Satisfied
# 357        29                          ['Station 33']             Satisfied
# 362        17  ['Station 12' 'Station 8' 'Station 5']             Satisfied
# 479         2             ['Station 24' 'Station 25']             Satisfied
# 489         3                          ['Station 39']             Satisfied
# 493        12                                      []             Satisfied
# 498        14                          ['Station 32']             Satisfied
# 503         1                          ['Station 30']             Satisfied
# 509        27                          ['Station 10']        Very Satisfied
# 512        16                          ['Station 21']        Very Satisfied
# 525         4                                      []        Very Satisfied
# 527        30                           ['Station 6']        Very Satisfied
# 530        22                          ['Station 37']             Satisfied
# 533        19               ['Station 9' 'Station 2']             Satisfied
# 732        23                           ['Station 7']             Satisfied
# 735        31                                      []             Satisfied
# 736        10                                      []        Very Satisfied
# 738        13              ['Station 15' 'Station 4']        Very Satisfied
# 749        28                                      []        Very Satisfied
# 750        15             ['Station 22' 'Station 28']             Satisfied
# 765        18                          ['Station 16']             Satisfied
# 787         9                          ['Station 38']             Satisfied
# 793        32                          ['Station 26']                   NaN
#
#     fire_services fire_response_time fire_professionalism
# 0       Satisfied          Satisfied           Don't Know
# 57      Satisfied          Satisfied           Don't Know
# 128     Satisfied          Satisfied           Don't Know
# 161     Satisfied          Satisfied              Neutral
# 164       Neutral          Satisfied       Very Satisfied
# 181     Satisfied          Satisfied       Very Satisfied
# 183    Don't Know         Don't Know           Don't Know
# 204    Don't Know         Don't Know           Don't Know
# 231    Don't Know         Don't Know           Don't Know
# 344    Don't Know         Don't Know           Don't Know
# 354     Satisfied          Satisfied            Satisfied
# 357     Satisfied          Satisfied            Satisfied
# 362    Don't Know         Don't Know           Don't Know
# 479     Satisfied         Don't Know           Don't Know
# 489     Satisfied         Don't Know           Don't Know
# 493     Satisfied          Satisfied            Satisfied
# 498     Satisfied          Satisfied            Satisfied
# 503     Satisfied          Satisfied            Satisfied
# 509     Satisfied          Satisfied            Satisfied
# 512     Satisfied          Satisfied            Satisfied
# 525     Satisfied          Satisfied            Satisfied
# 527     Satisfied          Satisfied            Satisfied
# 530     Satisfied          Satisfied            Satisfied
# 533    Don't Know         Don't Know           Don't Know
# 732     Satisfied         Don't Know            Satisfied
# 735     Satisfied          Satisfied       Very Satisfied
# 736     Satisfied          Satisfied       Very Satisfied
# 738     Satisfied          Satisfied            Satisfied
# 749     Satisfied          Satisfied            Satisfied
# 750     Satisfied         Don't Know            Satisfied
# 765     Satisfied         Don't Know            Satisfied
# 787     Satisfied            Neutral           Don't Know
# 793           NaN                NaN                  NaN

# %% [markdown]
# [('permits',), ('station_dist',), ('strp',), ('survey',)]
# [('building_permits',), ('fire_stations',), ('resident_survey',), ('short_term_permits',)]

# %% [markdown]
# SELECT Orders.OrderID, Customers.CustomerName, Orders.OrderDate
# FROM Orders
# INNER JOIN Customers ON Orders.CustomerID=Customers.CustomerID

# %%
db = 'multi_table_2.db'
con = sql.connect(db)
mycursor = con.cursor()
mycursor.execute("SELECT * FROM strp_2018 LEFT JOIN station_dist ON strp_2018.council_district=station_dist.district")
two_tables=(mycursor.fetchall())
#print(two_tables)

# %%
pd.DataFrame(two_tables)
# Out:
#               0                                 1  \
# 0    2018024546  Jamia Richmond & Zachary Bentley
# 1    2018006025                        Adam Klenk
# 2    2018010131                       Sarah Upton
# 3    2018067475                      Micah Sannan
# 4    2018070389                 The Lease Killers
# ..          ...                               ...
# 818  2018010922                     Legree Graham
# 819  2018060708                     Kevin Douglas
# 820  2017072307                              None
# 821  2018044963                   Curtis Ortmeier
# 822  2018020388                       Steve Dumas
#
#                                     2                                   3  \
# 0    Jamia Richmond & Zachary Bentley  Short Term Rental - Owner Occupied
# 1                        Nestive, LLC     Short Term Rental � Multifamily
# 2                         Sarah Upton  Short Term Rental - Owner Occupied
# 3                        Micah Sannan  Short Term Rental - Owner Occupied
# 4                   The Lease Killers     Short Term Rental � Multifamily
# ..                                ...                                 ...
# 818                     Legree Graham     Short Term Rental � Multifamily
# 819                     Kevin Douglas  Short Term Rental - Owner Occupied
# 820                   Kevin Henderson     Short Term Rental � Multifamily
# 821                   Curtis Ortmeier  Short Term Rental - Owner Occupied
# 822                       Steve Dumas  Short Term Rental - Owner Occupied
#
#            4               5                       6  \
# 0     ISSUED  071070D00200CO  05/01/2018 12:00:00 AM
# 1     ISSUED  104020R00400CO  02/01/2018 12:00:00 AM
# 2     ISSUED  092090V00200CO  02/22/2018 12:00:00 AM
# 3     ISSUED     06115035900  10/24/2018 12:00:00 AM
# 4    EXPIRED     10409018800  11/07/2018 12:00:00 AM
# ..       ...             ...                     ...
# 818   ISSUED     09215012700  02/27/2018 12:00:00 AM
# 819  EXPIRED     08106040700  09/24/2018 12:00:00 AM
# 820   ISSUED  104080L10500CO  11/08/2017 12:00:00 AM
# 821   ISSUED     00700020800  07/31/2018 12:00:00 AM
# 822   ISSUED     07203036200  04/12/2018 12:00:00 AM
#
#                               7                       8  \
# 0    2018-05-10 00:00:00.000000  05/10/2020 12:00:00 AM
# 1    2018-03-02 00:00:00.000000  03/02/2020 12:00:00 AM
# 2    2018-03-02 00:00:00.000000  03/02/2020 12:00:00 AM
# 3    2018-11-07 00:00:00.000000  11/07/2020 12:00:00 AM
# 4    2018-12-11 00:00:00.000000  12/11/2019 12:00:00 AM
# ..                          ...                     ...
# 818  2018-03-06 00:00:00.000000  03/06/2020 12:00:00 AM
# 819  2018-10-09 00:00:00.000000  10/09/2019 12:00:00 AM
# 820  2018-02-02 00:00:00.000000  02/02/2020 12:00:00 AM
# 821  2018-08-07 00:00:00.000000  08/07/2020 12:00:00 AM
# 822  2018-05-01 00:00:00.000000  05/01/2020 12:00:00 AM
#
#                              9              10  11     12  \
# 0               304  QUEEN AVE       NASHVILLE  TN  37207
# 1       3181  PARTHENON AVE  4       NASHVILLE  TN  37203
# 2             420B  37TH AVE N       NASHVILLE  TN  37209
# 3           3814  KATHERINE ST       NASHVILLE  TN  37216
# 4           3715  WEST END AVE       NASHVILLE  TN  37205
# ..                         ...             ...  ..    ...
# 818  2110  ELLISTON PL  203-21       NASHVILLE  TN  37203
# 819           1828  25TH AVE N       NASHVILLE  TN  37208
# 820       1504  18TH AVE S 105       NASHVILLE  TN  37212
# 821            2099  TINNIN RD  GOODLETTSVILLE  TN  37072
# 822         1208B  SHELTON AVE       NASHVILLE  TN  37216
#
#                                                     13  \
# 0    By making this application for a Residential S...
# 1    By making this application for a Type 3 Reside...
# 2    By making this application for a Type 1 Reside...
# 3    By making this application for a Residential S...
# 4    By making this application for Short Term Rent...
# ..                                                 ...
# 818  By making this application for a Type 3 Reside...
# 819  By making this application for a Residential S...
# 820  By making this application for a Type 3 Reside...
# 821  By making this application for a Residential S...
# 822  Note: STRP permit is for rear dwelling only. N...
#
#                                14    15    16                        17    18  \
# 0                            None  CASR   5.0  2018024546071070D00200CO   5.0
# 1                      Adam Klenk  CASR  21.0  2018006025104020R00400CO  21.0
# 2    UPTON, SARAH J. & BRANDON M.  CASR  24.0  2018010131092090V00200CO  24.0
# 3    RINCK, AMBER & SANNAN, MICAH  CASR   7.0     201806747506115035900   7.0
# 4            WEHRLY HOLDINGS, LLC  CASR  24.0     201807038910409018800  24.0
# ..                            ...   ...   ...                       ...   ...
# 818          I & G ELLISTON, INC.  CASR  21.0     201801092209215012700  21.0
# 819              HELMS, CHARMAINE  CASR  21.0     201806070808106040700  21.0
# 820         FERNLAND RENTALS, LLC  CASR  17.0  2017072307104080L10500CO  17.0
# 821      ORTMEIER, CURTIS & HOLLY  CASR  10.0     201804496300700020800  10.0
# 822             DUMAS, STEPHEN C.  CASR   7.0     201802038807203036200   7.0
#
#                                          19
# 0                             ['Station 3']
# 1               ['Station 11' 'Station 19']
# 2               ['Station 13' 'Station 17']
# 3               ['Station 29' 'Station 18']
# 4               ['Station 13' 'Station 17']
# ..                                      ...
# 818             ['Station 11' 'Station 19']
# 819             ['Station 11' 'Station 19']
# 820  ['Station 12' 'Station 8' 'Station 5']
# 821                                      []
# 822             ['Station 29' 'Station 18']
#
# [823 rows x 20 columns]

# %%
two_tables_pd = pd.read_sql_query("SELECT station_dist.district, station_dist.station_number, resident_survey_2018.fire_and_ems__overall, resident_survey_2018.fire_services, resident_survey_2018.fire_response_time, resident_survey_2018.fire_professionalism  FROM strp_2018 INNER JOIN resident_survey_2018 ON resident_survey_2018.zip_code = strp_2018.zip LEFT JOIN station_dist ON station_dist.district = strp_2018.council_district", sql.connect('multi_table_2.db'))

# %%
two_tables_pd.drop_duplicates('district').sort_values('district').reset_index(drop=True)
# Out:
#     district                          station_number fire_and_ems__overall  \
# 0        1.0                          ['Station 30']             Satisfied
# 1        2.0             ['Station 24' 'Station 25']             Satisfied
# 2        3.0                          ['Station 39']        Very Satisfied
# 3        4.0                                      []        Very Satisfied
# 4        5.0                           ['Station 3']             Satisfied
# 5        6.0                          ['Station 14']             Satisfied
# 6        7.0             ['Station 29' 'Station 18']             Satisfied
# 7        8.0              ['Station 1' 'Station 31']             Satisfied
# 8        9.0                          ['Station 38']             Satisfied
# 9       10.0                                      []             Satisfied
# 10      11.0                          ['Station 36']             Satisfied
# 11      12.0                                      []             Satisfied
# 12      13.0              ['Station 15' 'Station 4']             Satisfied
# 13      14.0                          ['Station 32']             Satisfied
# 14      15.0             ['Station 22' 'Station 28']             Satisfied
# 15      16.0                          ['Station 21']             Satisfied
# 16      17.0  ['Station 12' 'Station 8' 'Station 5']             Satisfied
# 17      18.0                          ['Station 16']             Satisfied
# 18      19.0               ['Station 9' 'Station 2']               Neutral
# 19      20.0                          ['Station 23']             Satisfied
# 20      21.0             ['Station 11' 'Station 19']             Satisfied
# 21      22.0                          ['Station 37']             Satisfied
# 22      23.0                           ['Station 7']             Satisfied
# 23      24.0             ['Station 13' 'Station 17']             Satisfied
# 24      25.0                          ['Station 20']             Satisfied
# 25      26.0                          ['Station 27']        Very Satisfied
# 26      27.0                          ['Station 10']        Very Satisfied
# 27      28.0                                      []        Very Satisfied
# 28      29.0                          ['Station 33']        Very Satisfied
# 29      30.0                           ['Station 6']        Very Satisfied
# 30      31.0                                      []             Satisfied
# 31      33.0                          ['Station 35']             Satisfied
# 32       NaN                                    None             Satisfied
#
#    fire_services fire_response_time fire_professionalism
# 0      Satisfied          Satisfied            Satisfied
# 1      Satisfied         Don't Know           Don't Know
# 2     Don't Know         Don't Know           Don't Know
# 3      Satisfied          Satisfied            Satisfied
# 4      Satisfied         Don't Know           Don't Know
# 5      Satisfied          Satisfied           Don't Know
# 6        Neutral          Satisfied       Very Satisfied
# 7        Neutral          Satisfied       Very Satisfied
# 8      Satisfied            Neutral           Don't Know
# 9      Satisfied            Neutral           Don't Know
# 10     Satisfied          Satisfied              Neutral
# 11     Satisfied          Satisfied            Satisfied
# 12     Satisfied         Don't Know            Satisfied
# 13     Satisfied          Satisfied            Satisfied
# 14     Satisfied         Don't Know            Satisfied
# 15     Satisfied          Satisfied           Don't Know
# 16    Don't Know         Don't Know           Don't Know
# 17     Satisfied         Don't Know            Satisfied
# 18       Neutral            Neutral              Neutral
# 19    Don't Know         Don't Know           Don't Know
# 20    Don't Know         Don't Know           Don't Know
# 21     Satisfied          Satisfied            Satisfied
# 22     Satisfied         Don't Know            Satisfied
# 23    Don't Know         Don't Know           Don't Know
# 24     Satisfied          Satisfied       Very Satisfied
# 25     Satisfied          Satisfied            Satisfied
# 26     Satisfied          Satisfied            Satisfied
# 27     Satisfied          Satisfied            Satisfied
# 28     Satisfied          Satisfied            Satisfied
# 29     Satisfied          Satisfied            Satisfied
# 30     Satisfied          Satisfied       Very Satisfied
# 31     Satisfied          Satisfied            Satisfied
# 32    Don't Know         Don't Know           Don't Know

# %% [markdown]
# SELECT O.OrderNumber, CONVERT(date,O.OrderDate) AS Date,
#        P.ProductName, I.Quantity, I.UnitPrice
#   FROM [Order] O
#   JOIN OrderItem I ON O.Id = I.OrderId
#   JOIN Product P ON P.Id = I.ProductId
# ORDER BY O.OrderNumber
#
#
# SELECT station_dist.district, station_dist.station_number, survey.fire_and_ems__overall, survey.fire_services, survey.fire_response_time, survey.fire_professionalism  FROM strp  INNER JOIN survey ON survey.zip_code = strp.zip  LEFT JOIN station_dist ON station_dist.dist = strp.zip
