# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd # not for students, install from anaconda gui
# ^^ Had dependency issues when installing geopandas from cli, but I remember an issue with fiona package...
# Also need to install descartes through anaconda gui, but don't need to import?
import numpy as np
import re
from shapely.geometry import Point
import sqlite3 as sql
from sqlalchemy import create_engine

# %matplotlib inline

# %%
pd.set_option('max_colwidth', 500)

# %%
permits = pd.read_csv('data/Building_Permits_Issued.csv', low_memory=False)
print(permits.shape)
permits.head()
# Out:
# (34474, 20)
#      Permit #      Permit Type Description       Permit Subtype Description  \
# 0  2019067152   Building Demolition Permit  Demolition Permit - Residential
# 1  2019011084     Building Use & Occupancy            Multifamily, Townhome
# 2  2019011479  Building Commercial - Rehab        Restaurant (Full Service)
# 3  2019039568   Building Residential - New          Single Family Residence
# 4  2017000049   Building Residential - New          Single Family Residence
#
#            Parcel Date Entered Date Issued  Construction Cost  \
# 0     06106005200   11/01/2019  11/01/2019             6000.0
# 1  051100J90000CO   02/25/2019  07/22/2019                0.0
# 2     11714005500   02/27/2019  07/22/2019           759670.0
# 3  085040A40800CO   07/03/2019  07/22/2019           300888.0
# 4  164100A43100CO   01/03/2017  01/09/2017           268107.0
#
#                         Address       City State    ZIP  \
# 0             600  MAPLEWOOD LN  NASHVILLE    TN  37216
# 1                812  BRIAR CIR    MADISON    TN  37115
# 2  2171  GREEN HILLS VILLAGE DR  NASHVILLE    TN  37215
# 3         4327  STONE HALL BLVD  HERMITAGE    TN  37076
# 4              704  ABERCORN CT    ANTIOCH    TN  37013
#
#                               Subdivision / Lot  \
# 0       S SIDE MAPLEWOOD LANE & W OF HUTSON AVE
# 1                    COMMON AREA HOMES AT BRIAR
# 2     W/S HILLSBORO PK. & N/S ABBOTT MARTIN RD.
# 3  LOT 408 THE RESERVE AT STONE HALL PH 2 SEC 1
# 4    LOT 79 SUMMERFIELD SUBDIVISION VILLAGE TEN
#
#                               Contact Permit Type Permit Subtype  \
# 0          CONTRERAS DESIGN BUILD LLC        CADM      CAZ01A001
# 1                COLE INVESTMENTS LLC        CAUO      CAA03R301
# 2  BATTINO CONTRACTING SOLUTIONS, LLC        CACR      CAF19A203
# 3     MERITAGE HOMES OF TENNESSEE INC        CARN      CAA01R301
# 4            NVR, INC. T/A RYAN HOMES        CARN      CAA01R301
#
#    IVR Tracking #  \
# 0         3728422
# 1         3611315
# 2         3613106
# 3         3687554
# 4         3306701
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Purpose  \
# 0                                                                                                                                                                                                                                                                         to demolish existing residence and detached storage building.  not to be burned on lot.  for every 50' site frontage, a 24  x 36  d/f sign must be placed in English and Spanish with information in regards to metro council bill 2017-835.
# 1                                                                                                                                                                                                                                                                                              MASTER PERMIT ONLY� � NO CONSTRUCTION� �MULTI-FAMILY SP� � 17 DETACHED RESIDENTIAL UNITS� � \n\nMUST COMPLY WITH SPECIFIC PLAN (SP) 2017SP-093   \n\nPARCELS 05110004000, 05110004100 AND 05110004200  MUST BE COMBINED
# 2                                                                                                                                                                                                                                                                                                                                                                                                                           2475 sq.ft. build out of CAVA RESTURANT to include new kitchen\nPOC ADAM TOAL 202-719-0111
# 3                                                                                                     New Single Family construction - Total Sq footage 4133 - 1st fl 1076; 2nd fl 939; Finished basement 656; unfinished basement 939; garage 417; porch/patio 106.  PUDR.  must comply with tree regulations one new two inch tree for every 30' road frontage.  for every 50' site frontage, a 24  x 36  d/f sign must be placed in English and Spanish with information in regards to metro council bill 2017-835.
# 4  TO CONSTRUCT A NEW SINGLE FAMILY RES AT 2380 SQFT WITH ATTACHED GARAGE AT 421 SQFT WITH PORCHES AND DECKS.....SETBACKS MIN 20'...REAR MIN 20'..SIDE MIN 5'...SEE PLAN..For every 30 feet of LOT frontage, or fraction thereof, one 2 inch caliper tree as listed in the Urban Forestry approved tree list shall be planted on the subject property....Pursuant Ordinance # 2006-1263  Metropolitan code of Laws, I (the holder on this permit)   hereby certify that all construction & demolition waste generat...
#
#    Council District  Census Tract  \
# 0               8.0    37011002.0
# 1               8.0    37010802.0
# 2              25.0    37017901.0
# 3              14.0    37015402.0
# 4              32.0    37015630.0
#
#                                                              Mapped Location
# 0             600 MAPLEWOOD LN\nNASHVILLE, TN 37216\n(36.228473, -86.740798)
# 1                                           812 BRIAR CIR\nMADISON, TN 37115
# 2  2171 GREEN HILLS VILLAGE DR\nNASHVILLE, TN 37215\n(36.108463, -86.814234)
# 3                                  4327 STONE HALL BLVD\nHERMITAGE, TN 37076
# 4                704 ABERCORN CT\nANTIOCH, TN 37013\n(36.045042, -86.616211)

# %%
permits.columns
# Out:
# Index(['Permit #', 'Permit Type Description', 'Permit Subtype Description',
#        'Parcel', 'Date Entered', 'Date Issued', 'Construction Cost', 'Address',
#        'City', 'State', 'ZIP', 'Subdivision / Lot', 'Contact', 'Permit Type',
#        'Permit Subtype', 'IVR Tracking #', 'Purpose', 'Council District',
#        'Census Tract', 'Mapped Location'],
#       dtype='object')

# %%
permits.columns = ['number', 'type_desc', 'subtype_desc', 'parcel', 'enter_date', 'issue_date', 'cost', 'address', 'city', 
                   'state', 'zip', 'subdivision', 'contact', 'type_code', 'subtype_code', 'tracking_number', 'purpose', 'council_district',
                   'census_tract', 'mapped_location']

# %%
permits.head()
# Out:
#        number                    type_desc                     subtype_desc  \
# 0  2019067152   Building Demolition Permit  Demolition Permit - Residential
# 1  2019011084     Building Use & Occupancy            Multifamily, Townhome
# 2  2019011479  Building Commercial - Rehab        Restaurant (Full Service)
# 3  2019039568   Building Residential - New          Single Family Residence
# 4  2017000049   Building Residential - New          Single Family Residence
#
#            parcel  enter_date  issue_date      cost  \
# 0     06106005200  11/01/2019  11/01/2019    6000.0
# 1  051100J90000CO  02/25/2019  07/22/2019       0.0
# 2     11714005500  02/27/2019  07/22/2019  759670.0
# 3  085040A40800CO  07/03/2019  07/22/2019  300888.0
# 4  164100A43100CO  01/03/2017  01/09/2017  268107.0
#
#                         address       city state    zip  \
# 0             600  MAPLEWOOD LN  NASHVILLE    TN  37216
# 1                812  BRIAR CIR    MADISON    TN  37115
# 2  2171  GREEN HILLS VILLAGE DR  NASHVILLE    TN  37215
# 3         4327  STONE HALL BLVD  HERMITAGE    TN  37076
# 4              704  ABERCORN CT    ANTIOCH    TN  37013
#
#                                     subdivision  \
# 0       S SIDE MAPLEWOOD LANE & W OF HUTSON AVE
# 1                    COMMON AREA HOMES AT BRIAR
# 2     W/S HILLSBORO PK. & N/S ABBOTT MARTIN RD.
# 3  LOT 408 THE RESERVE AT STONE HALL PH 2 SEC 1
# 4    LOT 79 SUMMERFIELD SUBDIVISION VILLAGE TEN
#
#                               contact type_code subtype_code  tracking_number  \
# 0          CONTRERAS DESIGN BUILD LLC      CADM    CAZ01A001          3728422
# 1                COLE INVESTMENTS LLC      CAUO    CAA03R301          3611315
# 2  BATTINO CONTRACTING SOLUTIONS, LLC      CACR    CAF19A203          3613106
# 3     MERITAGE HOMES OF TENNESSEE INC      CARN    CAA01R301          3687554
# 4            NVR, INC. T/A RYAN HOMES      CARN    CAA01R301          3306701
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                purpose  \
# 0                                                                                                                                                                                                                                                                         to demolish existing residence and detached storage building.  not to be burned on lot.  for every 50' site frontage, a 24  x 36  d/f sign must be placed in English and Spanish with information in regards to metro council bill 2017-835.
# 1                                                                                                                                                                                                                                                                                              MASTER PERMIT ONLY� � NO CONSTRUCTION� �MULTI-FAMILY SP� � 17 DETACHED RESIDENTIAL UNITS� � \n\nMUST COMPLY WITH SPECIFIC PLAN (SP) 2017SP-093   \n\nPARCELS 05110004000, 05110004100 AND 05110004200  MUST BE COMBINED
# 2                                                                                                                                                                                                                                                                                                                                                                                                                           2475 sq.ft. build out of CAVA RESTURANT to include new kitchen\nPOC ADAM TOAL 202-719-0111
# 3                                                                                                     New Single Family construction - Total Sq footage 4133 - 1st fl 1076; 2nd fl 939; Finished basement 656; unfinished basement 939; garage 417; porch/patio 106.  PUDR.  must comply with tree regulations one new two inch tree for every 30' road frontage.  for every 50' site frontage, a 24  x 36  d/f sign must be placed in English and Spanish with information in regards to metro council bill 2017-835.
# 4  TO CONSTRUCT A NEW SINGLE FAMILY RES AT 2380 SQFT WITH ATTACHED GARAGE AT 421 SQFT WITH PORCHES AND DECKS.....SETBACKS MIN 20'...REAR MIN 20'..SIDE MIN 5'...SEE PLAN..For every 30 feet of LOT frontage, or fraction thereof, one 2 inch caliper tree as listed in the Urban Forestry approved tree list shall be planted on the subject property....Pursuant Ordinance # 2006-1263  Metropolitan code of Laws, I (the holder on this permit)   hereby certify that all construction & demolition waste generat...
#
#    council_district  census_tract  \
# 0               8.0    37011002.0
# 1               8.0    37010802.0
# 2              25.0    37017901.0
# 3              14.0    37015402.0
# 4              32.0    37015630.0
#
#                                                              mapped_location
# 0             600 MAPLEWOOD LN\nNASHVILLE, TN 37216\n(36.228473, -86.740798)
# 1                                           812 BRIAR CIR\nMADISON, TN 37115
# 2  2171 GREEN HILLS VILLAGE DR\nNASHVILLE, TN 37215\n(36.108463, -86.814234)
# 3                                  4327 STONE HALL BLVD\nHERMITAGE, TN 37076
# 4                704 ABERCORN CT\nANTIOCH, TN 37013\n(36.045042, -86.616211)

# %% [markdown]
# ---

# %%
permits.info()

# type_desc, subtype_desc, cost, issue_date - enter_date, zip, contact?, type_code, concil_district
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34474 entries, 0 to 34473
# Data columns (total 20 columns):
# number              34474 non-null object
# type_desc           34474 non-null object
# subtype_desc        34474 non-null object
# parcel              34474 non-null object
# enter_date          34474 non-null object
# issue_date          34474 non-null object
# cost                34458 non-null float64
# address             34474 non-null object
# city                34472 non-null object
# state               34472 non-null object
# zip                 34474 non-null int64
# subdivision         34474 non-null object
# contact             34473 non-null object
# type_code           34474 non-null object
# subtype_code        34474 non-null object
# tracking_number     34474 non-null int64
# purpose             34019 non-null object
# council_district    34422 non-null float64
# census_tract        34409 non-null float64
# mapped_location     34474 non-null object
# dtypes: float64(3), int64(2), object(15)
# memory usage: 5.3+ MB

# %%
# do something where they have to separate residential and commercial permits
permits['type_desc'].value_counts()
# Out:
# Building Residential - New                  13142
# Building Commercial - Rehab                  3457
# Building Residential - Rehab                 3345
# Building Residential - Addition              3264
# Building Demolition Permit                   2855
# Building Sign Permit                         2438
# Building Use & Occupancy                     1572
# Building Commercial - Tenant Finish Out      1063
# Building Commercial - New                     972
# Building Tree Removal Permit                  479
# Building Commercial - Addition                477
# Building Commercial - Roofing / Siding        255
# Building Residential - Roofing / Siding       246
# Building Commercial - Shell                   149
# Building Blasting Permit                      144
# Building Residential - Tenant Finish Out      143
# Building Commercial - Foundation              109
# Building Residential - Fire Damage             99
# Building Residential - Change Contractor       91
# Building Commercial - Fire Damage              52
# Building Residential - Amend Permit            34
# Building Commercial - Structural Frame         32
# Building Moving Permit                         16
# Building Residential - Foundation              12
# Building Residential - Shell                   10
# Building Residential - Storm Damage             9
# Building Commercial - Change Contractor         7
# Building Commercial - Storm Damage              1
# Building Residential - Renew Permit             1
# Name: type_desc, dtype: int64

# %%
# Maybe something with this, could be good for matplotlib bar plot
permits['subtype_desc'].value_counts()
# Out:
# Single Family Residence                  15965
# Demolition Permit - Residential           2420
# Sign - Ground /  Wall Signs               2343
# Accessory Structure, Garage               1304
# General Office, Professional Services     1294
#                                          ...
# Comm. Amusement (Out), Bleachers             1
# Small Outdoor Music Event                    1
# Historical Bed & Breakfast, Hotel            1
# College / University, Libraries              1
# General Office, Courtrooms                   1
# Name: subtype_desc, Length: 180, dtype: int64

# %%
permits['cost'].value_counts()
# Out:
# 2000.0      929
# 1.0         883
# 5000.0      839
# 10000.0     647
# 15000.0     538
#            ...
# 629714.0      1
# 8743.0        1
# 5564.0        1
# 2299.0        1
# 14777.0       1
# Name: cost, Length: 8104, dtype: int64

# %%
# What was the highest cost for a permit? What was the lowest? How many of each?
permits.describe()
# Out:
#                cost           zip  tracking_number  council_district  \
# count  3.445800e+04  34474.000000     3.447400e+04      34422.000000
# mean   3.047219e+05  37153.689592     3.500911e+06         17.728604
# std    2.169379e+06    942.331091     1.610342e+05          9.330480
# min    0.000000e+00      0.000000     1.623298e+06          1.000000
# 25%    9.000000e+03  37203.000000     3.390344e+06         10.000000
# 50%    5.912900e+04  37208.000000     3.501985e+06         19.000000
# 75%    2.168230e+05  37211.000000     3.611583e+06         24.000000
# max    1.314127e+08  37240.000000     3.740784e+06         35.000000
#
#        census_tract
# count  3.440900e+04
# mean   1.555413e+08
# std    2.319147e+09
# min    1.250000e+04
# 25%    3.701320e+07
# 50%    3.701563e+07
# 75%    3.701820e+07
# max    4.703702e+10

# %%
plt.figure(figsize = (20, 10))
plt.hist(permits['cost'], bins = 100);
# Out:
# /Users/maheshrao/anaconda3/envs/jumpstart/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/maheshrao/anaconda3/envs/jumpstart/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Which person or group had the most permits (exclude self contractors)?
permits['contact'].value_counts()
# Out:
# SELF CONTRACTOR RESIDENTIAL (SEE APPLICANT INFORMATION)    3061
# SELF CONTRACTOR COMMERCIAL (SEE APPLICANT INFORMATION)      746
# OLE SOUTH PROPERTIES INC                                    601
# NVR, INC. T/A RYAN HOMES                                    581
# JOSLIN SIGN & MAINTENANCE CO INC                            520
#                                                            ...
# JACK PIRATAS PARTNERSHIP                                      1
# Jonathan Sanders                                              1
# DORRIS, PHILIP  CONSTRUCTION                                  1
# SELF CONTRACTOR RESIDENTIAL (ROGER LEE)                       1
# HARPETH RESTORATION, LLC                                      1
# Name: contact, Length: 4555, dtype: int64

# %%
permits['zip'].value_counts()
# Out:
# 37209    4005
# 37013    3092
# 37203    2511
# 37207    2261
# 37206    2065
# 37211    1974
# 37208    1930
# 37215    1450
# 37205    1299
# 37216    1290
# 37076    1277
# 37221    1242
# 37214    1174
# 37210    1133
# 37115    1131
# 37212    1075
# 37204     971
# 37217     729
# 37138     674
# 37218     508
# 37135     489
# 37027     463
# 37201     359
# 37219     322
# 37220     215
# 37072     181
# 37228     173
# 37189     172
# 37080     126
# 37213      60
# 37086      27
# 0          21
# 37122      18
# 37143      14
# 37064      13
# 37015      10
# 37238       9
# 37232       6
# 37240       1
# 37200       1
# 301         1
# 37235       1
# 27218       1
# Name: zip, dtype: int64

# %%
permits['enter_date'] = pd.to_datetime(permits['enter_date'])
permits['issue_date'] = pd.to_datetime(permits['issue_date'])

# %%
permits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34474 entries, 0 to 34473
# Data columns (total 20 columns):
# number              34474 non-null object
# type_desc           34474 non-null object
# subtype_desc        34474 non-null object
# parcel              34474 non-null object
# enter_date          34474 non-null datetime64[ns]
# issue_date          34474 non-null datetime64[ns]
# cost                34458 non-null float64
# address             34474 non-null object
# city                34472 non-null object
# state               34472 non-null object
# zip                 34474 non-null int64
# subdivision         34474 non-null object
# contact             34473 non-null object
# type_code           34474 non-null object
# subtype_code        34474 non-null object
# tracking_number     34474 non-null int64
# purpose             34019 non-null object
# council_district    34422 non-null float64
# census_tract        34409 non-null float64
# mapped_location     34474 non-null object
# dtypes: datetime64[ns](2), float64(3), int64(2), object(13)
# memory usage: 5.3+ MB

# %%
# What is the longest time a permit took to be issued?

permits['enter_date'] = pd.to_datetime(permits['enter_date'])
permits['issue_date'] = pd.to_datetime(permits['issue_date'])
(permits['issue_date']-permits['enter_date']).value_counts()
# Out:
# 0 days       10804
# 1 days        2246
# 7 days        1123
# 6 days        1089
# 2 days        1080
#              ...
# 1212 days        1
# 701 days         1
# 421 days         1
# 540 days         1
# 1391 days        1
# Length: 491, dtype: int64

# %%
# subset by year and compare

# %%
short_term_permits = pd.read_csv('data/Residential_Short_Term_Rental_Permits.csv')

# %%
short_term_permits.head()
# Out:
#       Permit #             Applicant Applicant Home Phone  \
# 0   2018054778  Brookside Properties                  NaN
# 1   2017067571                   NaN                  NaN
# 2  T2019048795      Shelley Matthews                  NaN
# 3   2018071612  Niido Nashville, LLC                  NaN
# 4   2017074493      Meredith Garrett                  NaN
#
#   Applicant Mobile Phone Applicant Work Phone Applicant Work Phone Ext.  \
# 0           615-496-5085                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2           757 373-4609                  NaN                       NaN
# 3           808 343-0834                  NaN                       NaN
# 4           615 485-0700                  NaN                       NaN
#
#                 Contact Contact Home Phone Contact Mobile Phone  \
# 0  Brookside Properties                NaN         615-496-5085
# 1          Sarah Butler                NaN         615 364-9634
# 2      Shelley Matthews                NaN         757 373-4609
# 3       Niido Nashville                NaN         615 440-0755
# 4      Meredith Garrett                NaN         615 485-0700
#
#   Contact Work Phone  ...   Permit Owner Addr. 2 Permit Owner Addr. 3  \
# 0                NaN  ...     5039 HILL PLACE DR                  NaN
# 1                NaN  ...    11 Music Sq. E #503                  NaN
# 2                NaN  ...         543 WESLEY AVE                  NaN
# 3                NaN  ...                    NaN                  NaN
# 4                NaN  ...  1715 6TH AVE N UNIT B                  NaN
#
#   Permit Owner City Permit Owner State Permit Owner ZIP Permit Type  \
# 0         NASHVILLE                 TN            37205        CASR
# 1         Nashville                 TN            37203        CASR
# 2         NASHVILLE                 TN            37207        CASR
# 3             MIAMI                 FL            33131        CASR
# 4         NASHVILLE                 TN            37208        CASR
#
#   Permit Subtype Council District Census Tract  \
# 0      CAZ10A003             19.0     37019500
# 1      CAZ10A003             19.0     37019500
# 2      CAZ10A001              5.0     37011300
# 3      CAZ10A003             19.0     37019500
# 4      CAZ10A001             19.0     37019400
#
#                                                    Mapped Location
# 0    109 2ND AVE N 1\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 1   11 MUSIC SQ E 503\nNASHVILLE, TN 37203\n(36.15108, -86.791727)
# 2     543 WESLEY AVE\nNASHVILLE, TN 37207\n(36.205997, -86.752678)
# 3  501 5TH AVE S 245\nNASHVILLE, TN 37203\n(36.155421, -86.775105)
# 4     1715B 6TH AVE N\nNASHVILLE, TN 37208\n(36.18254, -86.794409)
#
# [5 rows x 35 columns]

# %%
short_term_permits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 35 columns):
# Permit #                      9544 non-null object
# Applicant                     8459 non-null object
# Applicant Home Phone          38 non-null object
# Applicant Mobile Phone        4655 non-null object
# Applicant Work Phone          1474 non-null object
# Applicant Work Phone Ext.     2 non-null object
# Contact                       9095 non-null object
# Contact Home Phone            107 non-null object
# Contact Mobile Phone          5555 non-null object
# Contact Work Phone            3382 non-null object
# Contact Work Phone Ext.       2 non-null object
# Permit Subtype Description    9544 non-null object
# Permit Status                 9544 non-null object
# Parcel                        9544 non-null object
# Date Entered                  9544 non-null object
# Date Issued                   8421 non-null object
# Expiration Date               9540 non-null object
# Address                       9544 non-null object
# City                          9543 non-null object
# State                         9543 non-null object
# ZIP                           9544 non-null int64
# Subdivision / Lot             9542 non-null object
# Purpose                       9463 non-null object
# Permit Owner Name             8345 non-null object
# Permit Owner Addr. 1          1334 non-null object
# Permit Owner Addr. 2          7783 non-null object
# Permit Owner Addr. 3          29 non-null object
# Permit Owner City             8313 non-null object
# Permit Owner State            8302 non-null object
# Permit Owner ZIP              8320 non-null object
# Permit Type                   9544 non-null object
# Permit Subtype                9544 non-null object
# Council District              9537 non-null float64
# Census Tract                  9544 non-null int64
# Mapped Location               9544 non-null object
# dtypes: float64(1), int64(2), object(32)
# memory usage: 2.5+ MB

# %%
short_term_permits.describe()
# Out:
#                 ZIP  Council District  Census Tract
# count   9544.000000       9537.000000  9.544000e+03
# mean   37200.163349         15.245046  3.698855e+07
# std      381.631220          7.068474  1.001788e+06
# min        0.000000          1.000000  1.170000e+04
# 25%    37203.000000          7.000000  3.701260e+07
# 50%    37207.000000         18.000000  3.701630e+07
# 75%    37212.000000         19.000000  3.701900e+07
# max    37228.000000         35.000000  3.701960e+07

# %%
# Compare number of building permits and short term rental permits for each zip code (for a specific comparable year)
# Are the number of building and short term rental permits correlated?
# Are there zip that seem to have a particularly different ratio of building to short term rental permits?
# Can you find any reasons in the data why any differences might have occured?

permits_zip_vc = permits['zip'].value_counts().sort_index()
short_term_permits_zip_vc = short_term_permits['ZIP'].value_counts().sort_index()
permits_merge = pd.merge(permits_zip_vc, short_term_permits_zip_vc, how = 'inner', left_index = True, right_index = True)

plt.figure(figsize = (20, 10))
plt.bar(permits_merge.index.astype('str'), permits_merge['zip'])
plt.bar(permits_merge.index.astype('str'), permits_merge['ZIP'], alpha = 0.5)
plt.xticks(rotation = 90);

# %%
# You want to see how many building permits also had short term rental permits. Merge the two data sets on the 'parcel' column and check it out. Does one permit usually happen before the other?
parcel_join = pd.merge(permits, short_term_permits, left_on = 'parcel', right_on = 'Parcel', how = 'inner')
parcel_join
# Out:
#           number                        type_desc  \
# 0     2019067047  Building Residential - Addition
# 1     2019033051     Building Residential - Rehab
# 2     2019004523             Building Sign Permit
# 3     2019004523             Building Sign Permit
# 4     2019004523             Building Sign Permit
# ...          ...                              ...
# 6285  2018042889     Building Residential - Rehab
# 6286  2018037213       Building Residential - New
# 6287  2018075210     Building Residential - Rehab
# 6288  2018040060       Building Residential - New
# 6289  2018012713     Building Residential - Rehab
#
#                           subtype_desc          parcel enter_date issue_date  \
# 0              Single Family Residence     08207025700 2019-11-01 2019-11-01
# 1              Single Family Residence     11810013800 2019-06-05 2019-06-05
# 2          Sign - Ground /  Wall Signs     09306204700 2019-01-23 2019-06-05
# 3          Sign - Ground /  Wall Signs     09306204700 2019-01-23 2019-06-05
# 4          Sign - Ground /  Wall Signs     09306204700 2019-01-23 2019-06-05
# ...                                ...             ...        ...        ...
# 6285  Detached Accessory Dwelling Unit     11704012000 2018-07-23 2018-07-24
# 6286           Single Family Residence  093134Q00100CO 2018-06-26 2018-06-28
# 6287           Single Family Residence     06009000600 2018-11-30 2018-11-30
# 6288           Single Family Residence  093133D00200CO 2018-07-11 2018-07-23
# 6289           Single Family Residence     08106040700 2018-03-07 2018-03-07
#
#           cost                address       city state  ...  \
# 0       3500.0          226  BERRY ST  NASHVILLE    TN  ...
# 1      15000.0   3424  SPRINGBROOK DR  NASHVILLE    TN  ...
# 2       9000.0         109  2ND AVE N  NASHVILLE    TN  ...
# 3       9000.0         109  2ND AVE N  NASHVILLE    TN  ...
# 4       9000.0         109  2ND AVE N  NASHVILLE    TN  ...
# ...        ...                    ...        ...   ...  ...
# 6285    2000.0       1506  DALLAS AVE  NASHVILLE    TN  ...
# 6286  370055.0      1213A  HAWKINS ST  NASHVILLE    TN  ...
# 6287     200.0  2730  OLD MATTHEWS RD  NASHVILLE    TN  ...
# 6288  363522.0      1315B  HAWKINS ST  NASHVILLE    TN  ...
# 6289    5000.0       1828  25TH AVE N  NASHVILLE    TN  ...
#
#       Permit Owner Addr. 2 Permit Owner Addr. 3 Permit Owner City  \
# 0             226 BERRY ST                  NaN         NASHVILLE
# 1            116 GILMAN AV                  NaN         NASHVILLE
# 2       5039 HILL PLACE DR                  NaN         NASHVILLE
# 3       5039 HILL PLACE DR                  NaN         NASHVILLE
# 4       5039 HILL PLACE DR                  NaN         NASHVILLE
# ...                    ...                  ...               ...
# 6285       1506 DALLAS AVE                  NaN         NASHVILLE
# 6286     1213 A HAWKINS ST                  NaN         NASHVILLE
# 6287  2730 OLD MATTHEWS RD                  NaN         NASHVILLE
# 6288        1315 A Hawkins                  NaN         Nashville
# 6289       1828 25TH AVE N                  NaN         NASHVILLE
#
#      Permit Owner State Permit Owner ZIP  Permit Type Permit Subtype  \
# 0                    TN            37207         CASR      CAZ10A001
# 1                    TN            37205         CASR      CAZ10A002
# 2                    TN            37205         CASR      CAZ10A003
# 3                    TN            37205         CASR      CAZ10A003
# 4                    TN            37205         CASR      CAZ10A003
# ...                 ...              ...          ...            ...
# 6285                 TN            37212         CASR      CAZ10A001
# 6286                 TN            37203         CASR      CAZ10A002
# 6287                 TN            37207         CASR      CAZ10A001
# 6288                 TN            37203         CASR      CAZ10A001
# 6289                 TN            37208         CASR      CAZ10A001
#
#       Council District  Census Tract  \
# 0                  5.0      37012600
# 1                 25.0      37017800
# 2                 19.0      37019500
# 3                 19.0      37019500
# 4                 19.0      37019500
# ...                ...           ...
# 6285              18.0      37016900
# 6286              19.0      37016300
# 6287               2.0      37012701
# 6288              19.0      37016300
# 6289              21.0      37013700
#
#                                                         Mapped Location
# 0             226 BERRY ST\nNASHVILLE, TN 37207\n(36.181237, -86.76975)
# 1     3424 SPRINGBROOK DR\nNASHVILLE, TN 37204\n(36.110224, -86.779098)
# 2         109 2ND AVE N 1\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 3         109 2ND AVE N 6\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 4         109 2ND AVE N 3\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# ...                                                                 ...
# 6285      1506 DALLAS AVE\nNASHVILLE, TN 37212\n(36.123021, -86.792949)
# 6286     1213A HAWKINS ST\nNASHVILLE, TN 37203\n(36.148837, -86.786553)
# 6287   2730 OLD MATTHEWS RD\nNASHVILLE, TN 37207\n(36.21952, -86.79227)
# 6288     1315B HAWKINS ST\nNASHVILLE, TN 37203\n(36.148989, -86.787999)
# 6289      1828 25TH AVE N\nNASHVILLE, TN 37208\n(36.180965, -86.817809)
#
# [6290 rows x 55 columns]

# %%
permits[permits['parcel']=='09306204700']
# Out:
#            number                    type_desc                 subtype_desc  \
# 315    2019004523         Building Sign Permit  Sign - Ground /  Wall Signs
# 1437   2018057244  Building Commercial - Rehab    Restaurant (Full Service)
# 6872   2018014850         Building Sign Permit  Sign - Ground /  Wall Signs
# 9500   2018067830  Building Commercial - Rehab    Restaurant (Full Service)
# 16428  2018044984  Building Commercial - Rehab    Restaurant (Full Service)
#
#             parcel enter_date issue_date      cost         address       city  \
# 315    09306204700 2019-01-23 2019-06-05    9000.0  109  2ND AVE N  NASHVILLE
# 1437   09306204700 2018-09-07 2018-09-24   30000.0  109  2ND AVE N  NASHVILLE
# 6872   09306204700 2018-03-16 2018-06-29    7000.0  111  2ND AVE N  NASHVILLE
# 9500   09306204700 2018-10-25 2019-01-16  300000.0  109  2ND AVE N  NASHVILLE
# 16428  09306204700 2018-07-31 2018-08-17    5000.0  109  2ND AVE N  NASHVILLE
#
#       state    zip                           subdivision  \
# 315      TN  37201  PT LOT 30 ORIGINAL TOWN OF NASHVILLE
# 1437     TN  37201  PT LOT 30 ORIGINAL TOWN OF NASHVILLE
# 6872     TN  37201  PT LOT 30 ORIGINAL TOWN OF NASHVILLE
# 9500     TN  37201  PT LOT 30 ORIGINAL TOWN OF NASHVILLE
# 16428    TN  37201  PT LOT 30 ORIGINAL TOWN OF NASHVILLE
#
#                                 contact type_code subtype_code  \
# 315    JOSLIN SIGN & MAINTENANCE CO INC      CASN    CAZ02A001
# 1437              MP III MECHANICAL LLC      CACR    CAF19A203
# 6872                     SIGN ME UP LLC      CASN    CAZ02A001
# 9500              MP III MECHANICAL LLC      CACR    CAF19A203
# 16428             MP III MECHANICAL LLC      CACR    CAF19A203
#
#        tracking_number  \
# 315            3597302
# 1437           3557155
# 6872           3458862
# 9500           3572580
# 16428          3540677
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    purpose  \
# 315    to erect 20SF illuminated projecting sign for Music City Chicken Co.\nUL#: 9587242\n\n***PURSUANT TO ORDINANCE NO 2008-1263 of the Metropolitan Code of Laws, I , holder of this permit, hereby certify that all construction and demolition waste generated by any and all activities governed by this permit shall be disposed of in an approved landfill.  Further, I certify that no construction or demolition waste shall be stored on the property in violation of any provisions of the Metropolitan Cod...
# 1437                                                                                                                                                                                                                                                                                                                                                                  interior renovation for MUSIC CITY CHICKEN COMPANY  2300 SQ.FT. to include some structural and foundation slab work \nPOC STEVE SARGENT 817-666-5275
# 6872                                                                                                                                                                                                                                                                                                                                                            SIGN PERMIT FOR MARKET STREET MERCHANTILE...USING PROJECTION SIGN...104  X 36 ....UL...K 46701237...\n***THIS IS NOT A USE PERMIT....SIGN PERMIT ONLY.****
# 9500                                                                                                                                                                                                                   to conduct the final phase rehab work for Music City Chicken Company.  DTC, MHZC and MDHA Overlays.  Applicant requests John Tyler and Joseph Almon review this permit.  PUBLIC WORKS STAFF PLEASE NOTE:  SINCE PARCEL IS IN THE DTC, MPC WILL DETERMINE IF NEW SIDEWALKS ARE GOING TO BE REQUIRED.
# 16428                                                                                                                                                                                                                                                                                                                                                                        interior demo of existing approx. 2300 sq. ft. space for future restaurant FOR MUSIC CITY CHEICKEN COMPANY \nPOC STEPHEN SARGENT 817-666-5275
#
#        council_district  census_tract  \
# 315                19.0    37019500.0
# 1437               19.0    37019500.0
# 6872               19.0    37019500.0
# 9500               19.0    37019500.0
# 16428              19.0    37019500.0
#
#                                                    mapped_location
# 315    109 2ND AVE N\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 1437   109 2ND AVE N\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 6872   111 2ND AVE N\nNASHVILLE, TN 37201\n(36.162293, -86.775438)
# 9500   109 2ND AVE N\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 16428  109 2ND AVE N\nNASHVILLE, TN 37201\n(36.162228, -86.775394)

# %%
short_term_permits[short_term_permits['Parcel']=='09306204700']
# Out:
#         Permit #             Applicant Applicant Home Phone  \
# 0     2018054778  Brookside Properties                  NaN
# 5     2018054829  Brookside Properties                  NaN
# 9     2018054809  Brookside Properties                  NaN
# 23    2018054796  Brookside Properties                  NaN
# 26    2018054824  Brookside Properties                  NaN
# 406   2018054814  Brookside Properties                  NaN
# 6211  2018036681  Brookside Properties                  NaN
# 8022  2018054832  Brookside Properties                  NaN
#
#      Applicant Mobile Phone Applicant Work Phone Applicant Work Phone Ext.  \
# 0              615-496-5085                  NaN                       NaN
# 5              615-496-5085                  NaN                       NaN
# 9              615-496-5085                  NaN                       NaN
# 23             615-496-5085                  NaN                       NaN
# 26             615-496-5085                  NaN                       NaN
# 406            615-496-5085                  NaN                       NaN
# 6211           615 496-5085                  NaN                       NaN
# 8022           615-496-5085                  NaN                       NaN
#
#                    Contact Contact Home Phone Contact Mobile Phone  \
# 0     Brookside Properties                NaN         615-496-5085
# 5     Brookside Properties                NaN         615-496-5085
# 9     Brookside Properties                NaN         615-496-5085
# 23    Brookside Properties                NaN         615-496-5085
# 26    Brookside Properties                NaN         615-496-5085
# 406   Brookside Properties                NaN         615-496-5085
# 6211  Brookside Properties                NaN         615 496-5085
# 8022  Brookside Properties                NaN         615-496-5085
#
#      Contact Work Phone  ... Permit Owner Addr. 2 Permit Owner Addr. 3  \
# 0                   NaN  ...   5039 HILL PLACE DR                  NaN
# 5                   NaN  ...   5039 HILL PLACE DR                  NaN
# 9                   NaN  ...   5039 HILL PLACE DR                  NaN
# 23                  NaN  ...   5039 HILL PLACE DR                  NaN
# 26                  NaN  ...   5039 HILL PLACE DR                  NaN
# 406                 NaN  ...   5039 HILL PLACE DR                  NaN
# 6211                NaN  ...   5039 HILL PLACE DR                  NaN
# 8022                NaN  ...   5039 HILL PLACE DR                  NaN
#
#      Permit Owner City Permit Owner State Permit Owner ZIP Permit Type  \
# 0            NASHVILLE                 TN            37205        CASR
# 5            NASHVILLE                 TN            37205        CASR
# 9            NASHVILLE                 TN            37205        CASR
# 23           NASHVILLE                 TN            37205        CASR
# 26           NASHVILLE                 TN            37205        CASR
# 406          NASHVILLE                 TN            37205        CASR
# 6211         NASHVILLE                 TN            37205        CASR
# 8022         NASHVILLE                 TN            37205        CASR
#
#      Permit Subtype Council District Census Tract  \
# 0         CAZ10A003             19.0     37019500
# 5         CAZ10A003             19.0     37019500
# 9         CAZ10A003             19.0     37019500
# 23        CAZ10A003             19.0     37019500
# 26        CAZ10A003             19.0     37019500
# 406       CAZ10A003             19.0     37019500
# 6211      CAZ10A003             19.0     37019500
# 8022      CAZ10A003             19.0     37019500
#
#                                                     Mapped Location
# 0     109 2ND AVE N 1\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 5     109 2ND AVE N 6\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 9     109 2ND AVE N 3\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 23    109 2ND AVE N 2\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 26    109 2ND AVE N 5\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 406   109 2ND AVE N 4\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 6211  109 2ND AVE N 7\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
# 8022  109 2ND AVE N 8\nNASHVILLE, TN 37201\n(36.162228, -86.775394)
#
# [8 rows x 35 columns]

# %% [markdown]
# ---

# %%
permits.council_district.value_counts()
# Out:
# 19.0    2838
# 20.0    2364
# 17.0    2232
# 21.0    2002
# 5.0     1670
# 33.0    1601
# 6.0     1381
# 24.0    1380
# 2.0     1366
# 25.0    1311
# 7.0     1188
# 32.0     999
# 15.0     951
# 22.0     906
# 11.0     879
# 14.0     846
# 18.0     841
# 16.0     828
# 31.0     781
# 8.0      717
# 23.0     680
# 34.0     676
# 3.0      644
# 4.0      578
# 35.0     564
# 26.0     540
# 9.0      534
# 1.0      491
# 13.0     486
# 29.0     427
# 28.0     405
# 12.0     399
# 10.0     336
# 27.0     307
# 30.0     274
# Name: council_district, dtype: int64

# %%
beechwood = permits.loc[permits.address.str.contains('BEECHWOOD')]
beechwood
# Out:
#            number                                type_desc  \
# 2227   2019038377               Building Residential - New
# 4548   2019020333               Building Residential - New
# 5752   2019026170          Building Residential - Addition
# 6418   2019062410               Building Residential - New
# 6971   2019074099          Building Residential - Addition
# 8104   2019000729  Building Residential - Roofing / Siding
# 12349  2017073138          Building Residential - Addition
# 19144  2017049625          Building Residential - Addition
# 19236  2017034829             Building Residential - Rehab
# 23359  2019004963          Building Residential - Addition
# 26704  2018008344             Building Residential - Rehab
# 27145  2018058701               Building Residential - New
# 28125  2017037400             Building Residential - Rehab
# 29120  2018058696             Building Residential - Rehab
# 30054  2017049841             Building Residential - Rehab
#
#                            subtype_desc       parcel enter_date issue_date  \
# 2227   Detached Accessory Dwelling Unit  10416039400 2019-06-27 2019-07-02
# 4548        Accessory Structure, Garage  10415042900 2019-04-08 2019-05-16
# 5752            Single Family Residence  10416023700 2019-05-06 2019-05-06
# 6418   Detached Accessory Dwelling Unit  10416039400 2019-10-14 2019-11-26
# 6971            Single Family Residence  10415042700 2019-12-04 2019-12-09
# 8104            Single Family Residence  10513013400 2019-01-04 2019-01-10
# 12349           Single Family Residence  10416039800 2017-11-14 2017-11-20
# 19144        Accessory Structure, Decks  10416022300 2017-07-31 2017-08-14
# 19236       Accessory Structure, Garage  10416025100 2017-05-25 2017-05-25
# 23359        Accessory Structure, Decks  11704002900 2019-01-25 2019-01-29
# 26704           Single Family Residence  10415042700 2018-02-13 2018-02-13
# 27145       Accessory Structure, Garage  11704003100 2018-09-14 2018-09-21
# 28125       Accessory Structure, Garage  10513013100 2017-06-07 2017-07-21
# 29120           Single Family Residence  11704003100 2018-09-14 2018-09-14
# 30054           Single Family Residence  10416039500 2017-07-31 2017-08-04
#
#           cost               address       city state    zip  \
# 2227   69618.0   1516  BEECHWOOD AVE  NASHVILLE    TN  37212
# 4548   34455.0  2008B  BEECHWOOD AVE  NASHVILLE    TN  37212
# 5752   70000.0  1907B  BEECHWOOD AVE  NASHVILLE    TN  37212
# 6418   69618.0   1516  BEECHWOOD AVE  NASHVILLE    TN  37212
# 6971   70406.0   2012  BEECHWOOD AVE  NASHVILLE    TN  37212
# 8104   28455.0   1402  BEECHWOOD AVE  NASHVILLE    TN  37212
# 12349  65000.0   1508  BEECHWOOD AVE  NASHVILLE    TN  37212
# 19144  35000.0   1808  BEECHWOOD AVE  NASHVILLE    TN  37212
# 19236  81500.0   1815  BEECHWOOD AVE  NASHVILLE    TN  37212
# 23359  60000.0   1509  BEECHWOOD AVE  NASHVILLE    TN  37212
# 26704  15825.0   2012  BEECHWOOD AVE  NASHVILLE    TN  37212
# 27145  64000.0   1505  BEECHWOOD AVE  NASHVILLE    TN  37212
# 28125   3000.0   1306  BEECHWOOD AVE  NASHVILLE    TN  37212
# 29120  34000.0   1505  BEECHWOOD AVE  NASHVILLE    TN  37212
# 30054  23000.0   1514  BEECHWOOD AVE  NASHVILLE    TN  37212
#
#                                subdivision                         contact  \
# 2227            PT LOT 115 BELMONT LAND CO   HAMMOND & BRANDT BUILDERS LLC
# 4548   LOT 6 ESTATE OF DANIEL MCINTYRE SR.       PALMETTO CONSTRUCTION LLC
# 5752            PT LOT 222 BELMONT LAND CO                    mark cassani
# 6418            PT LOT 115 BELMONT LAND CO    BRITT DEVELOPMENT GROUP, LLC
# 6971   LOT 4 ESTATE OF DANIEL MCINTYRE SR.      MITCHELL CONSTRUCTION, LLC
# 8104                    LOT 2 WASHERS SUB.       MID SOUTH ALUMINUM CO INC
# 12349            PT LOT 88 BELMONT LAND CO              CRANE BUILDERS LLC
# 19144           PT LOT 211 BELMONT LAND CO             STRUCTURE CRAFT LLC
# 19236      PT LOTS 224 225 BELMONT LAND CO      GRAY, CARSON BUILDERS CORP
# 23359            PT LOT 91 BELMONT LAND CO  OSMAN CONSTRUCTION COMPANY LLC
# 26704  LOT 4 ESTATE OF DANIEL MCINTYRE SR.      MITCHELL CONSTRUCTION, LLC
# 27145            PT LOT 92 BELMONT LAND CO             EQUITY BUILDERS LLC
# 28125            PT LOT 83 BELMONT LAND CO                    Micah lacher
# 29120            PT LOT 92 BELMONT LAND CO             EQUITY BUILDERS LLC
# 30054            PT LOT 89 BELMONT LAND CO           ROJO CONSTRUCTION LLC
#
#       type_code subtype_code  tracking_number  \
# 2227       CARN    CAA11R301          3685598
# 4548       CARN    CAA14U009          3648775
# 5752       CARA    CAA01R301          3666321
# 6418       CARN    CAA11R301          3721794
# 6971       CARA    CAA01R301          3738075
# 8104       CARK    CAA01R301          3591899
# 12349      CARA    CAA01R301          3423543
# 19144      CARA    CAA14U015          3390997
# 19236      CARR    CAA14U009          3369928
# 23359      CARA    CAA14U015          3597938
# 26704      CARR    CAA01R301          3446465
# 27145      CARN    CAA14U009          3559416
# 28125      CARR    CAA14U009          3373823
# 29120      CARR    CAA01R301          3559407
# 30054      CARR    CAA01R301          3391328
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    purpose  \
# 2227                                        existing parcel has a base zone of R8, contains 9150 sf lot area and is in a pre 1984 recorded subdivision.  this permit to construct a DADU residence with 748 sf garage and 618 sf living area.  see MHZC preservation permit 2019012315.  MHZC must review application.  for every 50' site frontage, a 24  x 36  d/f sign must be placed in English and Spanish with information in regards to metro council bill 2017-835.  Instrument recorded in book 20190701-0063823.
# 4548   Restrictive covenant filed. instrument 20190809-0079428.\n\nto construct 608SF detached garage to the rear of existing single family residence. not to be over any easements. not to be used for living space or commercial purposes. \nMUST COMPLY WITH HCN2018069215\n***PURSUANT TO ORDINANCE NO 2008-1263 of the Metropolitan Code of Laws, I , holder of this permit, hereby certify that all construction and demolition waste generated by any and all activities governed by this permit shall be dispos...
# 5752   to construct 558SF addition and conduct interior rehab to existing residence. This residence is the rear residence of a non conforming duplex lot.\nMUST COMPLY WITH HCN2019013527\n\n***PURSUANT TO ORDINANCE NO 2008-1263 of the Metropolitan Code of Laws, I , holder of this permit, hereby certify that all construction and demolition waste generated by any and all activities governed by this permit shall be disposed of in an approved landfill.  Further, I certify that no construction or demolit...
# 6418                                                                                                                                                               parcel is zoned R8 and contains 9150 sf lot area.  this permit to construct a detached garage with a DADU residence.  MHZC must review application.  for every 50' site frontage, a 24  x 36  d/f sign must be placed in English and Spanish with information in regards to metro council bill 2017-835.  instrument recorded in book 20190701-0063823.
# 6971                                                                                                                                                                        to construct a 625 sf addition to rear of residence and install front dormers.  remains single family residence.  MHZC must review application.  for every 50' site frontage, a 24  x 36  d/f sign must be placed in English and Spanish with information in regards to metro council bill 2017-835.  see MHZC preservation permit 2019014013.
# 8104                                                                                                                                                                                                                                                                                                                                                                                                                                                                      INSTALL SIDING AND GUTTERS TO SINGLE FAMILY RES.
# 12349  MHZC review/approval prior to permit issuance. See MHZC permit 2017068416. To construct a 17 ft x 12'6  (250 +/- sq ft) addition to rear of existing single family residence. Additional work to include renovating existing deck and front porch. No change to footprint of deck or porch, renovations only. Must conform with all easements on property. Setbacks to be reviewed/determined by MHZC. No second kitchen or commercial use permitted. Pursuant to Ordinance No. 2006-1263 of the Metropolitan co...
# 19144                                                                                                                                                                                                                                                                                                                                                                         to construct an unheated 290 sf screen porch addition to rear of residence.  remains single family residence.  MHZC MUST REVIEW APPLICATION.
# 19236  DETACHED STRUCTURE RESTRICTIVE COVENANT 20170809-0081347\n\nto conduct interior renovations and replace roof of existing detached garage. no change to footprint. not to be used for living space or commercial purposes.\n***PURSUANT TO ORDINANCE NO 2008-1263 of the Metropolitan Code of Laws, I , holder of this permit, hereby certify that all construction and demolition waste generated by any and all activities governed by this permit shall be disposed of in an approved landfill.  Further, I ce...
# 23359                                                                                                           to demolish existing rear deck and construct a 16 x 24 screen porch and a 10 x 12 uncovered deck to rear of residence.  also conduct general repairs to existing residence.  MHZC must review application.  under 50% accessed value of improvements.  for every 50' site frontage, a 24  x 36  d/f sign must be placed in English and Spanish with information in regards to metro council bill 2017-835.
# 26704                                                                                                                                                                                                                                                                                                                                                to conduct interior and exterior renovations to existing residence.  remains single family residence.  MHZC must review application.  subject to inspectors approval.
# 27145  RESTRICTIVE COVENANT FOR DETACHED STRUCTURE RECORDED 201809210093782\nAROBINSON (09-24-2018 01:17PM)\nMHZC to review/approve prior to permit issuance. MHZC Permit 2018058993\nTo construct a 26 ft x  28 ft(728 sq ft) detached single story garage. Not to be used for living or commercial purposes. Restrictive Covenant to be filed prior to any trade authorizations. Must comply with all easements on property. Pursuant Ordinance # 2006-1263  Metropolitan code of Laws, I (the holder on this permit)...
# 28125  This permit to construct wall to separate a min. 88SF of interior to create storage space. This will bring living space under 700SF which is the maximum allowed for the DADU. Per ZA\n\nTotal square footage is 787SF, once permit is complete will have no greater than 699SF of living space and a minimum of 88SF of storage space.\n\nthis permit must have use and occupancy issued before the DADU permit (T201617521) is signed off and issued.\n\nPursuant # 2006-1263  Metrocode of Laws, I (holder OF...
# 29120  Interior renovations to kitchen in existing single family residence. No change to exterior. Remains single family.\nPursuant Ordinance # 2006-1263  Metropolitan code of Laws, I (the holder on this permit)   hereby certify that all construction & demolition waste generated by any & all activities governed by this permit shall be disposed of in an approved landfill. Further, I certify that no construction & demolition waste shall be stored on the property in violation of any provision of  Metr...
# 30054                                                                                                                                                                                                                                                                                                                                                to conduct exterior general repairs to existing residence.  triple fee to be applied per inspection.  remains single family residence.  MHZC must review application.
#
#        council_district  census_tract  \
# 2227               18.0    37016900.0
# 4548               18.0    37016900.0
# 5752               18.0    37016900.0
# 6418               18.0    37016900.0
# 6971               18.0    37016900.0
# 8104               18.0    37016900.0
# 12349              18.0    37016900.0
# 19144              18.0    37016900.0
# 19236              18.0    37016900.0
# 23359              18.0    37016900.0
# 26704              18.0    37016900.0
# 27145              18.0    37016900.0
# 28125              18.0    37016900.0
# 29120              18.0    37016900.0
# 30054              18.0    37016900.0
#
#                                                          mapped_location
# 2227    1516 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.125633, -86.793297)
# 4548   2008B BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.126899, -86.802612)
# 5752   1907B BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.126613, -86.800918)
# 6418    1516 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.125633, -86.793297)
# 6971    2012 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.126931, -86.803012)
# 8104    1402 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.125416, -86.791268)
# 12349   1508 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.125567, -86.792611)
# 19144   1808 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.126426, -86.799067)
# 19236   1815 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.126496, -86.799788)
# 23359    1509 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.12557, -86.792646)
# 26704   2012 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.126931, -86.803012)
# 27145   1505 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.125533, -86.792268)
# 28125   1306 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.125358, -86.790757)
# 29120   1505 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.125533, -86.792268)
# 30054   1514 BEECHWOOD AVE\nNASHVILLE, TN 37212\n(36.125621, -86.793173)

# %%
fire_stations = pd.read_csv('data/Fire_Stations.csv')
fire_stations.head()
# Out:
#   Station Number        Street Address         City State  Zip Code  \
# 0      Station 6      377 Haywood Lane    Nashville    TN     37211
# 1     Station 29    4201 Gallatin Road    Nashville    TN     37216
# 2     Station 20    1626 Harding Place    Nashville    TN     37215
# 3      Station 3   840 Meridian Avenue    Nashville    TN     37207
# 4     Station 36  1000 Donelson Street  Old Hickory    TN     37138
#
#                                                         Mapped Location
# 0        377 Haywood Lane\nNashville, TN 37211\n(36.068801, -86.716832)
# 1      4201 Gallatin Road\nNashville, TN 37216\n(36.224081, -86.725628)
# 2         1626 Harding Place\nNashville, TN 37215\n(36.0911, -86.82559)
# 3     840 Meridian Avenue\nNashville, TN 37207\n(36.186602, -86.768085)
# 4  1000 Donelson Street\nOld Hickory, TN 37138\n(36.264093, -86.648087)

# %%
fire_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
# Station Number     40 non-null object
# Street Address     40 non-null object
# City               40 non-null object
# State              40 non-null object
# Zip Code           40 non-null int64
# Mapped Location    39 non-null object
# dtypes: int64(1), object(5)
# memory usage: 2.0+ KB

# %%
fire_stations['Zip Code'].value_counts()
# Out:
# 37211    4
# 37013    3
# 37207    3
# 37115    2
# 37072    2
# 37203    2
# 37205    2
# 37206    2
# 37210    2
# 37209    2
# 37212    2
# 37214    2
# 37221    2
# 37204    1
# 37080    1
# 37215    1
# 37216    1
# 37076    1
# 37217    1
# 37138    1
# 37201    1
# 37218    1
# 37208    1
# Name: Zip Code, dtype: int64

# %%
# Could ask a leading question of what stations are in what zip code then lead into using sql to better answer

# %%
lat_lng_pattern = re.compile(r'\((.*),\s*(.*)\)', flags=re.MULTILINE)

def extract_lat_lng(address):
    try:
        lat_lng_match = lat_lng_pattern.search(address)
        lat = float(lat_lng_match.group(1))
        lng = float(lat_lng_match.group(2))
        return (lat, lng)
    except:
        return (np.NaN, np.NaN)  #it's important that our list be exactly as long as our df

# %%
lat_lngs = [extract_lat_lng(location) for location in fire_stations.loc[:, 'Mapped Location']]

fire_stations['lat'] = [lat for lat, lng in lat_lngs]
fire_stations['lng'] = [lng for lat, lng in lat_lngs]

# alternate way: list(zip(*lat_lngs))

# %%
districts = gpd.read_file('data/council_districts.geojson')
districts.head(2)
# Out:
#   first_name                           email     res_phone     bus_phone  \
# 0       Nick     nick.leonardo@nashville.gov  615-509-6334  615-862-6780
# 1    DeCosta  decosta.hastings@nashville.gov  615-779-1565  615-862-6780
#
#   last_name        position district  \
# 0  Leonardo  Council Member        1
# 1  Hastings  Council Member        2
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               geometry
# 0  MULTIPOLYGON (((-86.90738 36.39052, -86.90725 36.39048, -86.90712 36.39046, -86.90709 36.39046, -86.90709 36.39046, -86.90702 36.39045, -86.90679 36.39036, -86.90655 36.39027, -86.90654 36.39026, -86.90634 36.39016, -86.90609 36.39005, -86.90590 36.38997, -86.90573 36.38994, -86.90561 36.38991, -86.90552 36.38989, -86.90550 36.38988, -86.90550 36.38988, -86.90540 36.38982, -86.90532 36.38975, -86.90529 36.38973, -86.90522 36.38968, -86.90511 36.38962, -86.90492 36.38957, -86.90485 36.38955, ...
# 1  MULTIPOLYGON (((-86.75902 36.23091, -86.75909 36.23053, -86.75910 36.23046, -86.75919 36.22997, -86.75922 36.22985, -86.75926 36.22959, -86.75929 36.22944, -86.75930 36.22939, -86.75936 36.22894, -86.75940 36.22867, -86.75941 36.22865, -86.75947 36.22830, -86.75957 36.22790, -86.75977 36.22716, -86.75988 36.22682, -86.75997 36.22656, -86.76022 36.22587, -86.76026 36.22575, -86.76038 36.22536, -86.76042 36.22524, -86.76053 36.22493, -86.76058 36.22479, -86.76072 36.22440, -86.76083 36.22410, ...

# %%
districts['centroid'] = districts['geometry'].centroid

# %%
districts.head(2)
# Out:
#   first_name                           email     res_phone     bus_phone  \
# 0       Nick     nick.leonardo@nashville.gov  615-509-6334  615-862-6780
# 1    DeCosta  decosta.hastings@nashville.gov  615-779-1565  615-862-6780
#
#   last_name        position district  \
# 0  Leonardo  Council Member        1
# 1  Hastings  Council Member        2
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               geometry  \
# 0  MULTIPOLYGON (((-86.90738 36.39052, -86.90725 36.39048, -86.90712 36.39046, -86.90709 36.39046, -86.90709 36.39046, -86.90702 36.39045, -86.90679 36.39036, -86.90655 36.39027, -86.90654 36.39026, -86.90634 36.39016, -86.90609 36.39005, -86.90590 36.38997, -86.90573 36.38994, -86.90561 36.38991, -86.90552 36.38989, -86.90550 36.38988, -86.90550 36.38988, -86.90540 36.38982, -86.90532 36.38975, -86.90529 36.38973, -86.90522 36.38968, -86.90511 36.38962, -86.90492 36.38957, -86.90485 36.38955, ...
# 1  MULTIPOLYGON (((-86.75902 36.23091, -86.75909 36.23053, -86.75910 36.23046, -86.75919 36.22997, -86.75922 36.22985, -86.75926 36.22959, -86.75929 36.22944, -86.75930 36.22939, -86.75936 36.22894, -86.75940 36.22867, -86.75941 36.22865, -86.75947 36.22830, -86.75957 36.22790, -86.75977 36.22716, -86.75988 36.22682, -86.75997 36.22656, -86.76022 36.22587, -86.76026 36.22575, -86.76038 36.22536, -86.76042 36.22524, -86.76053 36.22493, -86.76058 36.22479, -86.76072 36.22440, -86.76083 36.22410, ...
#
#                      centroid
# 0  POINT (-86.89460 36.26267)
# 1  POINT (-86.80271 36.20859)

# %%
fig, ax = plt.subplots(figsize = (14, 14))
districts.plot(column = 'district', ax = ax, cmap = 'Set2', edgecolor = 'black')
for _, df in districts[['district', 'centroid']].iterrows():
    ax.annotate(df['district'], xy=(df['centroid'].x, df['centroid'].y), weight = 'bold')
plt.scatter(fire_stations.lng, fire_stations.lat, c = 'red')
;
# Out:
# ''

# %%
fire_stations['geometry'] = fire_stations.apply(lambda x: Point((float(x.lng), float(x.lat))), axis=1)

# %%
fire_geo = gpd.GeoDataFrame(fire_stations, crs = districts.crs, geometry = fire_stations.geometry)

# %%
fire_geo.head()
# Out:
#   Station Number        Street Address         City State  Zip Code  \
# 0      Station 6      377 Haywood Lane    Nashville    TN     37211
# 1     Station 29    4201 Gallatin Road    Nashville    TN     37216
# 2     Station 20    1626 Harding Place    Nashville    TN     37215
# 3      Station 3   840 Meridian Avenue    Nashville    TN     37207
# 4     Station 36  1000 Donelson Street  Old Hickory    TN     37138
#
#                                                         Mapped Location  \
# 0        377 Haywood Lane\nNashville, TN 37211\n(36.068801, -86.716832)
# 1      4201 Gallatin Road\nNashville, TN 37216\n(36.224081, -86.725628)
# 2         1626 Harding Place\nNashville, TN 37215\n(36.0911, -86.82559)
# 3     840 Meridian Avenue\nNashville, TN 37207\n(36.186602, -86.768085)
# 4  1000 Donelson Street\nOld Hickory, TN 37138\n(36.264093, -86.648087)
#
#          lat        lng                    geometry
# 0  36.068801 -86.716832  POINT (-86.71683 36.06880)
# 1  36.224081 -86.725628  POINT (-86.72563 36.22408)
# 2  36.091100 -86.825590  POINT (-86.82559 36.09110)
# 3  36.186602 -86.768085  POINT (-86.76808 36.18660)
# 4  36.264093 -86.648087  POINT (-86.64809 36.26409)

# %%
stations = gpd.sjoin(districts, fire_geo, op = 'contains' )
stations.head(2)
# Out:
# /Users/maheshrao/anaconda3/envs/jumpstart/lib/python3.7/site-packages/numpy/lib/function_base.py:2167: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)
#   first_name                           email     res_phone     bus_phone  \
# 0       Nick     nick.leonardo@nashville.gov  615-509-6334  615-862-6780
# 1    DeCosta  decosta.hastings@nashville.gov  615-779-1565  615-862-6780
#
#   last_name        position district  \
# 0  Leonardo  Council Member        1
# 1  Hastings  Council Member        2
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               geometry  \
# 0  MULTIPOLYGON (((-86.90738 36.39052, -86.90725 36.39048, -86.90712 36.39046, -86.90709 36.39046, -86.90709 36.39046, -86.90702 36.39045, -86.90679 36.39036, -86.90655 36.39027, -86.90654 36.39026, -86.90634 36.39016, -86.90609 36.39005, -86.90590 36.38997, -86.90573 36.38994, -86.90561 36.38991, -86.90552 36.38989, -86.90550 36.38988, -86.90550 36.38988, -86.90540 36.38982, -86.90532 36.38975, -86.90529 36.38973, -86.90522 36.38968, -86.90511 36.38962, -86.90492 36.38957, -86.90485 36.38955, ...
# 1  MULTIPOLYGON (((-86.75902 36.23091, -86.75909 36.23053, -86.75910 36.23046, -86.75919 36.22997, -86.75922 36.22985, -86.75926 36.22959, -86.75929 36.22944, -86.75930 36.22939, -86.75936 36.22894, -86.75940 36.22867, -86.75941 36.22865, -86.75947 36.22830, -86.75957 36.22790, -86.75977 36.22716, -86.75988 36.22682, -86.75997 36.22656, -86.76022 36.22587, -86.76026 36.22575, -86.76038 36.22536, -86.76042 36.22524, -86.76053 36.22493, -86.76058 36.22479, -86.76072 36.22440, -86.76083 36.22410, ...
#
#                      centroid  index_right Station Number  \
# 0  POINT (-86.89460 36.26267)           28     Station 30
# 1  POINT (-86.80271 36.20859)            8     Station 24
#
#               Street Address       City State  Zip Code  \
# 0  3705 Old Clarksville Pike    Joelton    TN     37080
# 1   3851 Clarksville Highway  Nashville    TN     37218
#
#                                                           Mapped Location  \
# 0   3705 Old Clarksville Pike\nJoelton, TN 37080\n(36.316384, -86.876877)
# 1  3851 Clarksville Highway\nNashville, TN 37218\n(36.203627, -86.840622)
#
#          lat        lng
# 0  36.316384 -86.876877
# 1  36.203627 -86.840622

# %% [markdown]
# #### looking at the shapes tells me I lost 2 fire stations when I did a spatial join. The one NE of the council districts makes sense...what about the other one?

# %%
fire_geo['Station Number'].isin(stations['Station Number'])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# Name: Station Number, dtype: bool

# %% [markdown]
# #### Station 41 is beyond council districts; Station 34 does not have lat/lng - will need to decide whether to geocode or drop 34

# %%
fire_stations.iloc[18:21, :]
# Out:
#    Station Number         Street Address            City State  Zip Code  \
# 18     Station 41     105 Long Hollow Pk  Goodlettsville    TN     37072
# 19     Station 17   3911 West End Avenue       Nashville    TN     37205
# 20     Station 34  8350 Highway 70 South       Nashville    TN     37221
#
#                                                           Mapped Location  \
# 18  105 Long Hollow Pk\nGoodlettsville, TN 37072\n(36.363516, -86.663892)
# 19      3911 West End Avenue\nNashville, TN 37205\n(36.13091, -86.835975)
# 20                                                                    NaN
#
#           lat        lng                geometry
# 18  36.363516 -86.663892  POINT (-86.664 36.364)
# 19  36.130910 -86.835975  POINT (-86.836 36.131)
# 20        NaN        NaN         POINT (nan nan)

# %%
stations = stations[['district', 'Station Number', 
                     'Street Address', 'City', 'State', 'Zip Code', 'lat', 'lng']]

# %%
stations.columns = ['district', 'station_number', 'address',
       'city', 'state', 'zipcode', 'lat', 'lng']

# %%
stations = stations.drop('zipcode', axis = 1)

# %%
# learn what this is doing

engine = create_engine('sqlite:///stations.db')

stations.to_sql('fire_stations', engine, index=False, if_exists='replace')

# %%
test = pd.read_sql('select * from fire_stations', engine)

# %%
test.shape
# Out:
# (38, 7)

# %%
test.head()
# Out:
#   district station_number                    address       city state  \
# 0        1     Station 30  3705 Old Clarksville Pike    Joelton    TN
# 1        2     Station 24   3851 Clarksville Highway  Nashville    TN
# 2        2     Station 25     2589 Whites Creek Pike  Nashville    TN
# 3        8      Station 1       130 Broadmoor Avenue  Nashville    TN
# 4        8     Station 31         415 Douglas Avenue    Madison    TN
#
#          lat        lng
# 0  36.316384 -86.876877
# 1  36.203627 -86.840622
# 2  36.215851 -86.801616
# 3  36.229579 -86.757426
# 4  36.259135 -86.716084
